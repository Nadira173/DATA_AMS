# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadira173/DATA_AMS/blob/main/Preprocessing_dan_visualisasi_program_sekolah_gratis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORT DATA

# %% [markdown]
# Untuk data mengenai keputusan MK terhadap sekolah negeri dan swasta gratis kami melakukan scrapping data dari X dan youtube API.

# %%
# !pip install squarify
# !pip install Sastrawi
# !pip install unidecode

import itertools, re, pickle
import time, operator, numpy as np, matplotlib.pyplot as plt, pandas as pd, seaborn as sns
import networkx as nx
import squarify
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.colors as mcolors
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
from matplotlib.colors import ListedColormap
from textblob import TextBlob
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from unidecode import unidecode
from nltk.tag import CRFTagger
from html import unescape
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from tqdm import tqdm
from wordcloud import WordCloud

"DONE!!!"
# Out:
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 'DONE!!!'

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/Nadira173/DATA_AMS/main/data%20fix%20-%20fulldata_with_sentiment.csv"

try:
    df = pd.read_csv(url)
    print(df.head())
except Exception as e:
    print("Terjadi kesalahan saat membaca file:", e)
# Out:
#                                                 text sentiment username  \
# 0  MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral      NaN
# 1  Komisi X DPR RI berkomitmen mengawal implement...   neutral      NaN
# 2  MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral      NaN
# 3  Respons Wamendagri Bima Arya soal Pendidikan G...   neutral      NaN
# 4  Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral      NaN
#
#                        created_at  likes  reply_count  \
# 0  Fri May 30 04:22:59 +0000 2025    1.0            0
# 1  Fri May 30 04:19:07 +0000 2025    0.0            0
# 2  Fri May 30 04:11:28 +0000 2025    3.0            2
# 3  Fri May 30 04:03:08 +0000 2025    3.0            0
# 4  Fri May 30 03:50:46 +0000 2025    0.0            0
#
#                                                  url
# 0  https://x.com/undefined/status/192830611885126...
# 1  https://x.com/undefined/status/192830514333582...
# 2  https://x.com/undefined/status/192830322054963...
# 3  https://x.com/undefined/status/192830112260070...
# 4  https://x.com/undefined/status/192829801043108...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5366 entries, 0 to 5365
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   text         5366 non-null   object
#  1   sentiment    5361 non-null   object
#  2   username     3699 non-null   object
#  3   created_at   5366 non-null   object
#  4   likes        5366 non-null   float64
#  5   reply_count  5366 non-null   int64
#  6   url          1667 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 293.6+ KB

# %%
df.columns
# Out:
# Index(['text', 'sentiment', 'username', 'created_at', 'likes', 'reply_count',
#        'url'],
#       dtype='object')

# %%
# Mengakses kolom 'sentiment' dari DataFrame df dan mendapatkan nilai unik
df['sentiment'].unique()
# Out:
# array(['neutral', 'negative', 'positive', nan, 'Positive'], dtype=object)

# %%
df['sentiment'] = df['sentiment'].replace('Positive', 'positive')

# %%
df['sentiment'].unique()
# Out:
# array(['neutral', 'negative', 'positive', nan], dtype=object)

# %%
# Mapping dari string ke angka
label_mapping = {
    'positive, Positive': 1,
    'neutral': 2,
    'negative': 3
}

df['sentiment_num'] = df['sentiment'].map(label_mapping)

print(df)
# Out:
#                                                    text sentiment  \
# 0     MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral
# 1     Komisi X DPR RI berkomitmen mengawal implement...   neutral
# 2     MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...   neutral
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral
# ...                                                 ...       ...
# 5361       Bagus itu gak semuanya org punya uang semoga  negative
# 5362  Nanti ukungnya di korop kalao semua di bebanka...  negative
# 5363  Hampang sj! Dana MBG alihkan sepenuhnya ke bia...  negative
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...   neutral
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...  negative
#
#                     username                      created_at  likes  \
# 0                        NaN  Fri May 30 04:22:59 +0000 2025    1.0
# 1                        NaN  Fri May 30 04:19:07 +0000 2025    0.0
# 2                        NaN  Fri May 30 04:11:28 +0000 2025    3.0
# 3                        NaN  Fri May 30 04:03:08 +0000 2025    3.0
# 4                        NaN  Fri May 30 03:50:46 +0000 2025    0.0
# ...                      ...                             ...    ...
# 5361     @ArdhiROBLOXCHANNEL              2025-05-30 2:37:07    0.0
# 5362            @hambali8442              2025-05-30 2:36:47    0.0
# 5363  @muhamadsmithwayne6496              2025-05-30 2:32:14    0.0
# 5364        @TimPublikasiFHO              2025-05-30 2:30:08    1.0
# 5365           @dinadidik641              2025-05-30 3:24:09    0.0
#
#       reply_count                                                url  \
# 0               0  https://x.com/undefined/status/192830611885126...
# 1               0  https://x.com/undefined/status/192830514333582...
# 2               2  https://x.com/undefined/status/192830322054963...
# 3               0  https://x.com/undefined/status/192830112260070...
# 4               0  https://x.com/undefined/status/192829801043108...
# ...           ...                                                ...
# 5361            0                                                NaN
# 5362            0                                                NaN
# 5363            0                                                NaN
# 5364            1                                                NaN
# 5365            0                                                NaN
#
#       sentiment_num
# 0               2.0
# 1               2.0
# 2               2.0
# 3               2.0
# 4               2.0
# ...             ...
# 5361            3.0
# 5362            3.0
# 5363            3.0
# 5364            2.0
# 5365            3.0
#
# [5366 rows x 8 columns]

# %%
df["created_at"] = pd.to_datetime(df["created_at"], errors='coerce', utc=True).dt.tz_localize(None)
# Out:
# <ipython-input-9-5d4955c7d875>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["created_at"] = pd.to_datetime(df["created_at"], errors='coerce', utc=True).dt.tz_localize(None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5366 entries, 0 to 5365
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   text           5366 non-null   object
#  1   sentiment      5361 non-null   object
#  2   username       3699 non-null   object
#  3   created_at     5366 non-null   datetime64[ns]
#  4   likes          5366 non-null   float64
#  5   reply_count    5366 non-null   int64
#  6   url            1667 non-null   object
#  7   sentiment_num  4507 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 335.5+ KB

# %% [markdown]
# #Slang

# %%
import json
import json

# Membaca file slang.json dari /content/
with open('/content/slang_cleaned_recovered.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Menampilkan data
data
# Menampilkan data
data
# Out:
# {'bakalan': 'akan',
#  'ngincer': 'mengincar',
#  'ga': 'tidak',
#  'tolol': 'bodoh',
#  'sampe': 'sampai',
#  'dll': 'dan lain-lain',
#  'duit': 'uang',
#  'ma': 'Madrasah Aliyah',
#  'herman': 'heran',
#  'utk': 'untuk',
#  'tdk': 'tidak',
#  'tsb': 'tersebut',
#  'yg': 'yang',
#  'ngomong': 'berbicara',
#  'g': 'tidak',
#  'udah': 'sudah',
#  'aja': 'saja',
#  'disitu': 'disana',
#  'jg': 'juga',
#  'ortu': 'orang tua',
#  'milih': 'memilih',
#  'nggak': 'tidak',
#  'pem': 'pemerintah',
#  'ngerasain': 'merasakan',
#  'mau': 'ingin',
#  'doang': 'saja',
#  'jd': 'jadi',
#  'emang': 'memang',
#  'loe': 'kamu',
#  'pembamgunan': 'pembangunan',
#  'gak': 'tidak',
#  'gw': 'saya',
#  'bikin': 'membuat',
#  'jgn': 'jangan',
#  'kls': 'kelas',
#  'dapet': 'dapat',
#  'ky': 'kayak',
#  'klo': 'kalau',
#  'dgratisin': 'digratiskan',
#  'ngemeng': 'ngomong',
#  'nnti': 'nanti',
#  'gimana': 'bagaimana',
#  'bilangnya': 'mengatakannya',
#  'dr': 'dari',
#  'ngga': 'tidak',
#  'skrg': 'sekarang',
#  'dikasih': 'diberikan',
#  'situ': 'kamu',
#  'gratisin': 'gratiskan',
#  'gk': 'tidak',
#  'nanggung': 'menanggung',
#  "bo'ong": 'bohong',
#  'gitu': 'begitu',
#  'aj': 'saja',
#  'kyk': 'kayak',
#  'ad': 'ada',
#  'gt': 'gitu',
#  'ngapain': 'mengapa',
#  'grgr': 'gara gara',
#  'ngikutin': 'mengikuti',
#  'gonta-ganti': 'berganti-ganti',
#  'mending': 'lebih baik',
#  'kasian': 'kasihan',
#  'bener': 'benar',
#  'sok-sokan': 'berlagak',
#  'ngutak atik': 'merecoki',
#  'kalo': 'kalau',
#  'ttp': 'tetap',
#  'kl': 'kalau',
#  'mbg': 'makan bergizi gratis',
#  'jt': 'juta',
#  'banget': 'sekali',
#  'lg': 'lagi',
#  'mang': 'emang',
#  'ea': 'betul',
#  'ni': 'ini',
#  'goblok': 'bodoh',
#  'indo': 'Indonesia',
#  'memding': 'lebih baik',
#  'bobrok': 'buruk sekali',
#  'lau': 'kamu',
#  'msh': 'masih',
#  'krn': 'karena',
#  'bs': 'bisa',
#  'lo': 'kamu',
#  'ngegratisin': 'menggratiskan',
#  'kek': 'kaya',
#  'imo': 'menurut saya',
#  'biar': 'agar',
#  'belajr': 'belajar',
#  'sklh': 'sekolah',
#  'sll': 'selalu',
#  'bln': 'bulan',
#  'raono': 'tidak ada',
#  'dri': 'dari',
#  'drj': 'dari',
#  'jga': 'juga',
#  'kyknya': 'sepertinya',
#  'dgn': 'dengan',
#  'negri': 'negeri',
#  'roboh': 'runtuh',
#  'ngajar': 'mengajar',
#  'ngisi': 'mengisi',
#  'kaya gitu': 'seperti itu',
#  'sarpras': 'sarana prasarana',
#  'keteteran': 'keteter',
#  'gaya-gayaan': 'bergaya',
#  'ngajuin': 'mengajukan',
#  'disunat': 'dipotong',
#  'diem': 'diam',
#  'bae': 'saja',
#  'ngurusin': 'mengurusi',
#  'cmn': 'cuma',
#  'cumin': 'hanya',
#  'cuma': 'hanya',
#  'tpi': 'tetapi',
#  'pd': 'pada',
#  'thn': 'tahun',
#  'kpd': 'kepada',
#  'gwe': 'saya',
#  'sbg': 'sebagai',
#  'dirugiin': 'dirugikan',
#  'ngasih': 'memberi',
#  'gede': 'besar',
#  'ngasi': 'ngasih',
#  'ngadelin': 'mengandalkan',
#  'nutup': 'menutupi',
#  'trs': 'terus',
#  'ngegaji': 'menggaji',
#  'spy': 'supaya',
#  'murmer': 'murah meriah',
#  'mo': 'mau',
#  'bayarin': 'membayarkan',
#  'jls': 'jelas',
#  'akn': 'akan',
#  'byrin': 'membayarkan',
#  'naikin': 'menaikkan',
#  'dapt': 'dapat',
#  'gua': 'saya',
#  'mendingan': 'lebih baik',
#  'nunggu': 'menunggu',
#  'neger': 'negeri',
#  'ngaco': 'sembarangan',
#  'bnyk': 'banyak',
#  'def': 'definisi',
#  'knp': 'kenapa',
#  'hrs': 'harus',
#  'org': 'orang',
#  'ntar': 'nanti',
#  'nggaaa': 'tidak',
#  'banyakan': 'lebih banyak',
#  'bloon': 'bodoh',
#  'pls': 'tolong',
#  'jamkos': 'jam kosong',
#  'rip': 'rest in peace',
#  'lagiihh': 'lagi',
#  'dlm': 'dalam',
#  'staf': 'pekerja',
#  'bos': 'bantuan operasional sekolah',
#  'rame2': 'beramai-ramai',
#  'aq': 'saya',
#  'dg': 'dengan',
#  'exkul': 'ekskul',
#  'gausah': 'tidak usah',
#  'ngrecokin': 'mengganggu',
#  'becus': 'mampu',
#  'gimans': 'gimana',
#  'mgk': 'mungkin',
#  'biarin': 'biarkan',
#  'aje': 'saja',
#  'nyuruh': 'menyuruh',
#  'perbaikin': 'perbaiki',
#  'sistim': 'sistem',
#  'enggak': 'tidak',
#  'masukin': 'memasukkan',
#  'pnya': 'mempunyai',
#  'ngapa': 'mengapa',
#  'laen2': 'lain-lain',
#  'nyenggol': 'mengganggu',
#  'benahin': 'perbaiki',
#  'gmna': 'bagaimana',
#  'nyentuh': 'menyentuh',
#  'apbn': 'Anggaran Pendapatan dan Belanja Negara',
#  'brtti': 'berarti',
#  'bego': 'bodoh',
#  'pmrth': 'pemerintah',
#  'mbayarin': 'membayarkan',
#  'pemerntah': 'pemerintah',
#  'gtu': 'begitu',
#  'tergant': 'tergantung',
#  'sm': 'sama',
#  'byk': 'banyak',
#  'kmren': 'kemarin',
#  'faham': 'paham',
#  'elo': 'kamu',
#  'skul': 'sekolah',
#  'apaan': 'apa',
#  'ngasal': 'asal',
#  'ucapab': 'ucapan',
#  'tar': 'nanti',
#  'bgm': 'bagaimana',
#  'trhalang': 'terhalang',
#  'kaget': 'terkejut',
#  'tau': 'tahu',
#  'mnrt': 'menurut',
#  'gabisa': 'tidak bisa',
#  'n': 'dan',
#  'ngide': 'memberikan ide',
#  'kyke': 'sepertinya',
#  'rd': 'rada',
#  'smua': 'semua',
#  'gth': 'begitu',
#  'nmun': 'namun',
#  'prtyaan': 'pertanyaan',
#  'hrus': 'harus',
#  'trkait': 'terkait',
#  'pndidik': 'pendidik',
#  'byar': 'bayar',
#  'sdgkan': 'sedangkan',
#  'rta': 'rata-rata',
#  'pr': 'para',
#  'swta': 'swasta',
#  'trus': 'terus',
#  'pkai': 'pakai',
#  'kgak': 'tidak',
#  'msalh': 'masalah',
#  'py': 'punya',
#  'dna': 'dana',
#  'mna': 'mana',
#  'prlu': 'perlu',
#  'pnjelsan': 'penjelasan',
#  'bedain': 'membedakan',
#  'rerata': 'rata-rata',
#  'ndak': 'tidak',
#  'palagi': 'apalagi',
#  'dlu': 'dulu',
#  'd': 'di',
#  'ansknya': 'anaknya',
#  'dah': 'sudah',
#  'bkn': 'bukan',
#  'sj': 'saja',
#  'terutm': 'terutama',
#  'orkay': 'orang kaya',
#  'kalok': 'kalau',
#  'ank': 'anak',
#  'brarti': 'berarti',
#  'asbun': 'asal bunyi',
#  'dn': 'dan',
#  'utang': 'hutang',
#  'tendik': 'tenaga pendidik',
#  'ngesahkan': 'mengesahkan',
#  'ngeri': 'mengerikan',
#  'bnr': 'benar',
#  'pingin': 'ingin',
#  'fajtanya': 'faktanya',
#  'kalean': 'kalian',
#  'swasto': 'swasta',
#  'trua': 'lalu',
#  'drpd': 'daripada',
#  'lbh': 'lebih',
#  'kadang2': 'terkadang',
#  'afa': 'ada',
#  'gefung': 'Gedung',
#  'sebenernya': 'sebetulnya',
#  'skolah': 'sekolah',
#  'dwngan': 'dengan',
#  'nga': 'tidak',
#  'semia': 'semua',
#  'smakin': 'semakin',
#  'mw': 'ingin',
#  'mrk': 'mereka',
#  'sy': 'saya',
#  'omon2': 'bicara',
#  'klu': 'kalau',
#  'ngutang': 'berhutang',
#  'omon omon': 'omong kosong',
#  'elu': 'kamu',
#  'pungli': 'pungutan liar',
#  'ndaftar': 'daftar',
#  'ndaftarin': 'mendaftarkan',
#  'atw': 'atau',
#  'memgkoveri': 'menutupi',
#  'mbayar': 'bayar',
#  'spt': 'seperti',
#  'kbnyakan': 'terlalu banyak',
#  'iyuran': 'iuran',
#  'bacot': 'cakap',
#  'hr': 'hari',
#  'mdh2an': 'semoga',
#  'ulangn': 'ujian',
#  'nm': 'nama',
#  'suwasta': 'swasta',
#  'nyoblos': 'memilih',
#  'mhn': 'mohon',
#  'jkt': 'jakarta',
#  'ajah': 'saja',
#  'geratis': 'gratis',
#  'mso': 'masa',
#  'bku': 'buku',
#  'mla': 'malah',
#  'hrap': 'harap',
#  'kecl': 'kecil',
#  'berhti': 'berhenti',
#  'jng': 'jangan',
#  'skalian': 'sekaligus',
#  'beaya': 'biaya',
#  'olh': 'oleh',
#  'sapa': 'siapa',
#  'ato': 'atau',
#  'ngg': 'tidak',
#  'koq': 'kok',
#  'kga': 'tidak',
#  'rencna': 'rencana',
#  'mncri': 'mencari',
#  'tmabhn': 'tambahan',
#  'ksih': 'berikan',
#  'propinsi': 'provinsi',
#  'mmg': 'memang',
#  'mksdny': 'maksudnya',
#  'drmn': 'darimana',
#  'plg': 'paling',
#  'kwalitas': 'kualitas',
#  'buanyak': 'banyak',
#  'abis': 'habis',
#  'Yuk': 'Ayo',
#  'Aa': 'Kakak',
#  'nggk': 'tidak',
#  'nda': 'tidak',
#  'bilang': 'mengatakan',
#  'yng': 'yang',
#  'UUD45': 'UUD 1945',
#  'UUD 45': 'UUD 1945',
#  'bgmn': 'bagaimana',
#  'apkh': 'apakah',
#  'Tok': 'Ketok',
#  'UU': 'Undang-Undang',
#  'sembilan': '9',
#  'Bro': 'teman',
#  'korup': 'korupsi',
#  'GW': 'SAYA',
#  'Gue': 'saya',
#  'gue': 'saya',
#  'blg': 'mengatakan',
#  'rb': 'ribu',
#  'brti': 'berarti',
#  'doank': 'saja',
#  'tp': 'tapi',
#  "Mkn'y": 'makanya',
#  'cm': 'cuma',
#  'dibawah': 'di bawah',
#  'guys': 'teman',
#  'setauku': 'setahu saya',
#  'liat': 'lihat',
#  'mk': 'maka',
#  'bakal': 'akan',
#  'digratisin': 'digratiskan',
#  'ilang': 'hilang',
#  'awalbya': 'awalnya',
#  'quota': 'kuota',
#  'cuan': 'keuntungan',
#  'grade': 'tingkatan',
#  'min': 'minimal',
#  'sbetulnya': 'sebetulnya',
#  'trmsuk': 'termasuk',
#  'msuk': 'masuk',
#  'pndidikan': 'pendidikan',
#  'mnengah': 'menengah',
#  'tis': 'gratis',
#  'ksatuan': 'kesatuan',
#  'bngsa': 'bangsa',
#  'ngeconya': 'kacau',
#  'koar2': 'teriak-teriak',
#  'gelem': 'mau',
#  'ora': 'tidak',
#  'mateng': 'matang',
#  'emak': 'ibu',
#  'sblm': 'sebelum',
#  'permennya': 'PERMEN nya',
#  'ksh': 'kasih',
#  'tai': 'umpatan',
#  'ledig': 'umpatan',
#  'yaelah': 'apa',
#  'gambil': 'ngambil',
#  'pande': 'pandai',
#  'pandean': 'pandaian',
#  'rame': 'ramai',
#  'nyekolahin': 'menyekolahkan',
#  'sepiiii': 'sepi',
#  'pulak': 'pula',
#  'NEGRI': 'NEGERI',
#  'UDAH': 'SUDAH',
#  'BLAS': 'SAMA SEKALI',
#  'auto': 'otomatis',
#  'kepentihgam': 'kepentingan',
#  'betkaitan': 'berkaitan',
#  'tang': 'yang',
#  'Pemrentah': 'Pemerintah',
#  'nyocot penak': 'ngomong enak',
#  'bnyak': 'banyak',
#  'kn': 'kan',
#  'blm': 'belum',
#  'iy': 'iya',
#  'Aya': 'ada',
#  'wae': 'saja',
#  'tu': 'itu',
#  'jir': 'umpatan',
#  'bjir': 'umpatan',
#  'njir': 'umpatan',
#  'njirr': 'umpatan',
#  'anjir': 'umpatan',
#  'hébaat': 'hebat',
#  'mmng': 'memang',
#  'sehrsnya': 'seharusnya',
#  'sdh': 'sudah',
#  'bgt': 'banget',
#  'kejuruaan': 'kejuruan',
#  'trtm': 'terutama',
#  'bg': 'bagi',
#  'ttg': 'tentang',
#  'Sy': 'Saya',
#  'w': 'saya',
#  'pdhl': 'padahal',
#  'Komen': 'Komentar',
#  'gada': 'tidak ada',
#  'lu': 'kamu',
#  'cowo': 'cowok',
#  'Ges': 'teman',
#  'mslh': 'masalah',
#  'Kl': 'kalau',
#  'sekolh': 'sekolah',
#  'Enggak': 'Tidak',
#  'engga': 'Tidak',
#  'korut': 'Korea Utara',
#  'dsb': 'dan sebagainya',
#  'tuh': 'itu',
#  'cuman': 'cuma',
#  'praktek': 'praktik',
#  'sekolah': 'sekolah',
#  'anjg': 'umpatan',
#  'PPEKKKK': 'umpatan',
#  'idiot': 'bodoh',
#  'anj': 'umpatan',
#  'topic': 'topik',
#  'ajg': 'umpatan',
#  'gblk': 'bodoh',
#  'bloonnya': 'bodoh',
#  'drpada': 'daripada',
#  'karna': 'karena',
#  'Emang': 'memang',
#  'noh': 'itu',
#  'mewujudkn': 'mewujudkan',
#  'sdm': 'sumber daya manusia',
#  'bgs': 'bagus',
#  'udh': 'sudah',
#  'Penyebanya': 'Penyebabnya',
#  'orng': 'orang',
#  'ngibul': 'bohong',
#  'pemakain': 'pemakaian',
#  'maluuuu': 'malu',
#  'karir': 'karier',
#  'Mskipn': 'Meskipun',
#  'jth': 'jatuh',
#  'mgkin': 'mungkin',
#  'mentrinya': 'menterinya',
#  'nginjek': 'nginjak',
#  'todak': 'tidak',
#  'njaminnsekolah': 'menjamin sekolah',
#  'papa': 'apa apa',
#  'samsek': 'sama sekali',
#  'mgkn': 'mungkin',
#  'masy': 'masyarakat',
#  'ttep': 'tetap',
#  'elit': 'elite',
#  'swastapun': 'swasta pun',
#  'suswa': 'siswa',
#  'dl': 'dulu',
#  'sbnrnya': 'sebenarnya',
#  'ujug': 'tiba',
#  'th': 'tahun',
#  'ngamokkk': 'ngamuk',
#  'ngamokkkk': 'ngamuk',
#  'mboh': 'tidak tahu',
#  'dpt': 'dapat',
#  'ind': 'indonesia',
#  'ygbpenting': 'yang penting',
#  'serem': 'seram',
#  'Swastapun': 'Swasta pun',
#  'thdp': 'terhadap',
#  'mjd': 'menjadi',
#  'dtg': 'datang',
#  'ndabrus': 'tidak jelas',
#  'danablah': 'dana lah',
#  'bntuk': 'bentuk',
#  'disurug': 'disuruh',
#  'seasta': 'swasta',
#  'sawasta': 'swasta',
#  'amay': 'amat',
#  'carmuk': 'cari muka',
#  'seuprit': 'sedikit',
#  'bahlul': 'bodoh',
#  'Diutuhkan': 'Dibutuhkan',
#  'cuen': 'keuntungan',
#  'masiih': 'masih',
#  'Mhn': 'mohon',
#  'sngt': 'sangat',
#  'ponakan': 'keponakan',
#  'invest': 'investasi',
#  'komit': 'komitmen',
#  'san': 'dan',
#  'Ade': 'adik',
#  'kite': 'kita',
#  'memutukan': 'memutuskan',
#  'swata': 'swasta',
#  'foku': 'fokus',
#  'TOTALOTAS': 'TOTALITAS',
#  'betatlah': 'beratlah',
#  'imdonesia': 'Indonesia',
#  'ngais': 'ngasih',
#  'pk': 'pakai',
#  'u': 'untuk',
#  'enih': 'ini',
#  'bnrn': 'beneran',
#  'staft': 'staf',
#  'staff': 'staf',
#  'disuru': 'disuruh',
#  'efisienshitt': 'efisiensi',
#  'kagk': 'tidak',
#  'kmpnk': 'umpatan',
#  'AJGG': 'umpatan',
#  'byeeee': 'selamat tinggal',
#  'mandeg': 'terhenti',
#  'sanggung': 'sanggup',
#  'tunggug': 'tunggu',
#  'Sklh': 'sekolah',
#  'Pd': 'pada',
#  'Ntar': 'nanti',
#  'Bgm': 'bagaimana',
#  'Gmn': 'bagaimana',
#  'ny': 'nya',
#  'ne': 'nya',
#  'walmur': 'wali murid',
#  'Emng': 'emang',
#  'Emg': 'emang',
#  'prshn': 'perusahaan',
#  'kynya': 'sepertinya',
#  'anggran': 'anggaran',
#  'dati': 'dari',
#  'yaa': 'ya',
#  'Nek': 'kalau',
#  'muk': 'mau',
#  'tok': 'saja',
#  'neken': 'menekan',
#  'orangtua': 'orang tua',
#  'perUUngan': 'per UU an',
#  'Indo': 'Indonesia',
#  'smpe': 'sampai',
#  'oprasional': 'operasional',
#  'curiculume': 'kurikulum',
#  'fav': 'favorit',
#  'tdnya': 'tadinya',
#  'adepin': 'hadapi',
#  'SIHH': 'sih',
#  'si': 'sih',
#  'pemrenta': 'pemerintah',
#  'berkwalitas': 'berkualitas',
#  'biasane': 'biasanya',
#  'Swastas': 'swasta',
#  'ntuh': 'itu',
#  'Sblum': 'sebelum',
#  'sgitu': 'segitu',
#  'lahh': 'lah',
#  'cius': 'serius',
#  'jdinya': 'jadinya',
#  'kocakkkk': 'kocak',
#  'DAUNNN': 'daun',
#  'pdhal': 'padahal',
#  'msk': 'masuk',
#  'bgus': 'bagus',
#  'kmblikn': 'kembalikan',
#  'pljrn': 'pelajaran',
#  'maen': 'main',
#  'muahal': 'mahal',
#  'pda': 'pada',
#  'gasalah': 'tidak salah',
#  'byr': 'bayar',
#  'NGIMPI': 'mimpi',
#  'diperes': 'diperas',
#  'adl': 'adalah',
#  'negrinya': 'negerinya',
#  'Kyknya': 'sepertinya',
#  'gratisyakin': 'gratis yakin',
#  'inter': 'internasional',
#  'scr': 'secara',
#  'maah': 'mah',
#  'gajelas': 'tidak jelas',
#  'OGAAAHHH': 'ogah',
#  'emanb': 'emang',
#  'jugaa': 'juga',
#  'gasi': 'tidak sih',
#  'kperluan': 'keperluan',
#  'trimakasih': 'terima kasih',
#  'Orgil': 'orang gila',
#  'sprti': 'seperti',
#  'pelososk': 'pelosok',
#  'pemerentah': 'pemerintah',
#  'bpk': 'bapak',
#  'dibiayin': 'dibiayain',
#  'gurune': 'gurunya',
#  'dibenbankan': 'dibebankan',
#  'dlsbg': 'dan sebagainya',
#  'pinter': 'pintar',
#  'mungking': 'mungkin',
#  'ak': 'saya',
#  'sgt': 'sangat',
#  'doble': 'double',
#  'punglin': 'pungli',
#  'bnget': 'banget',
#  'sedikir': 'sedikit',
#  'Klw': 'kalau',
#  'aplg': 'apalagi',
#  'bole': 'boleh',
#  'mamam': 'makan',
#  'sklhnya': 'sekolahnya',
#  'bedamya': 'bedanya',
#  'kobecanda': 'kok bercanda',
#  'puter': 'putar',
#  'standart': 'standar',
#  'gam': 'tidak',
#  'naekin': 'naikin',
#  'berboncong': 'berbondong',
#  'brantakan': 'berantakan',
#  'aga': 'agak',
#  'ngak': 'tidak',
#  'jumjur': 'jujur',
#  'sematakarena': 'semata karena',
#  'yatp': 'ya tetapi',
#  'yok': 'ayo',
#  'bknya': 'bukannya',
#  'oprasionalnya': 'operasionalnya',
#  'sikolah': 'sekolah',
#  'diperhatika': 'diperhatikan',
#  'namu': 'namun',
#  'skolh': 'sekolah',
#  'mungkn': 'mungkin',
#  'mumgkin': 'mungkin',
#  'lgipula': 'lagipula',
#  'Knapa': 'kenapa',
#  'knapa': 'kenapa',
#  'begimana': 'bagaimana',
#  'plis': 'tolong',
#  'make': 'pakai',
#  'bre': 'teman',
#  'gamau': 'tidak mau',
#  'Ngawoorrr': 'ngawur',
#  'kasik': 'kasih',
#  'lmyan': 'lumayan',
#  'duid': 'uang',
#  'sprt': 'seperti',
#  'kureng': 'kurang',
#  'beken': 'bagus',
#  'qualitynya': 'kualitasnya',
#  'quality': 'kualitas',
#  'Keknya': 'sepertinya',
#  'gakmungkin': 'tidak mungkin',
#  'ortunya': 'orang tuanya',
#  'duitnya': 'uangnya',
#  'semkin': 'semakin',
#  'k-merdeka': 'kurikulum merdeka',
#  'lgi': 'lagi',
#  'psti': 'pasti',
#  'qt': 'kita',
#  'sbgt': 'sebagai',
#  'ril': 'nyata',
#  'wkt': 'waktu',
#  'ituudh': 'itu sudah',
#  'anjlok': 'menurun',
#  'kemarinsekolah': 'kemarin sekolah',
#  'persemeternya': 'persemesternya',
#  'walkel': 'wali kelas',
#  'kepsek': 'kepala sekolah',
#  'BOSs': 'BOS',
#  'guruny': 'gurunya',
#  'jempur': 'jemput',
#  'ampe': 'sampai',
#  'nggaji': 'menggaji',
#  'seoengalaman': 'sepengalaman',
#  'sodara': 'saudara',
#  'daripasa': 'daripada',
#  'zekolah': 'sekolah',
#  'aer': 'air',
#  'khan': 'kan',
#  'semacam negri': 'seperti sekolah negeri',
#  'SPP': 'sumbangan pembinaan pendidikan',
#  'SDH': 'sudah',
#  'nilep': 'menggelapkan',
#  'bod..': 'bodoh',
#  'anak2': 'anak-anak',
#  'hp': 'handphone',
#  'sd,s/d': 'sampai dengan',
#  'ump.': 'umpamanya',
#  'program2': 'program-program',
#  'SD': 'Sekolah Dasar',
#  'SMP': 'Sekolah Menengah Pertama',
#  'soalnya': 'karena',
#  'ga,nggga,nggak': 'tidak',
#  'nih': 'ini',
#  'ini2': 'ini-ini',
#  'mudah mudahan': 'mudah-mudahan',
#  'pungutan2': 'pungutan-pungutan',
#  'LKS': 'Lembar Kerja Siswa',
#  'study tour': 'karya wisata',
#  'pak': 'bapak',
#  'Spp': 'SPP',
#  'eh tapi nih': 'namun ternyata',
#  'embel²': 'embel-embel',
#  'benar2': 'benar-benar',
#  'mansi': 'manis',
#  'seleuruh': 'seluruh',
#  'kah': 'benar kan?',
#  'dong': 'tentunya',
#  'hoax': 'informasi palsu',
#  'kepikiran': 'terpikirkan',
#  'dtambah lg': 'ditambah lagi',
#  'otak atik': 'utak-atik',
#  'lah': 'kok',
#  'tekor': 'rugi',
#  'gmn': 'bagaimana',
#  'team': 'tim',
#  'hidden gem': 'potensi tersembunyi',
#  'clear': 'jelas',
#  'di takuti': 'ditakuti',
#  'koutanya': 'kuotanya',
#  'maling': 'pencuri',
#  'les private': 'les privat',
#  'bimbel': 'bimbingan belajar',
#  'welcome to the future': 'selamat datang ke masa depan',
#  'MBG': 'Makan Bergizi Gratis',
#  'dagelan': 'lelucon',
#  'kayahhh rayah': 'kaya raya',
#  'ngaancurin': 'menghancurkan',
#  'mirim2': 'mirip-mirip',
#  'free': 'gratis',
#  'booking': 'memesan',
#  'UP': 'uang pangkal',
#  'crazy rich': 'orang sangat kaya',
#  'kabur': 'melarikan diri',
#  'gal gaalll total': 'gagal total',
#  'bau2': 'kecurigaan',
#  'thebest lh': 'terbaik',
#  'Konoha': 'Indonesia',
#  'downgrade': 'penurunan mutu',
#  'tetek-bengek': 'hal kecil yang merepotkan',
#  'dimana2': 'dimana-mana',
#  'prepesional': 'profesional',
#  'lgkap': 'lengkap',
#  'OOT': 'keluar dari pembahasan',
#  'Mdh2an': 'mudah-mudahan',
#  'bayr': 'bayar',
#  'syangnya': 'sayangnya',
#  'brants': 'berantas',
#  'senenge': 'senangnya',
#  'tlg': 'tolong',
#  'hrsnya': 'seharusnya',
#  'gblm': 'belum',
#  'mbeda2in': 'membeda-bedakan',
#  'twntu': 'tentu',
#  'biayaya': 'biayanya',
#  'miski': 'miskin',
#  'gx': 'tidak',
#  'smga': 'semoga',
#  'daerh2': 'daerah-daerah',
#  'dipake': 'dipakai',
#  'nwgri': 'negeri',
#  'dibiaya': 'dibiayai',
#  'mbangun': 'membangun',
#  'hayalan': 'khayalan',
#  'kalu': 'kalau',
#  'geleng2': 'geleng-geleng',
#  'kepal': 'kepala',
#  'derah': 'daerah',
#  'kadng': 'kadang',
#  'klw': 'kalau',
#  'krng': 'kurang',
#  'teros': 'terus',
#  'harusnys': 'harusnya',
#  'skup': 'lingkup',
#  'ko': 'kok',
#  'gratid': 'gratis',
#  'modar': 'mati',
#  'setengah': 'setengah',
#  'siwa': 'siswa',
#  'bangat': 'banget',
#  'sdkolah': 'sekolah',
#  'geratiss': 'gratis',
#  'swatah': 'swasta',
#  'ramai. RAMAI.': 'ramai-ramai',
#  'pinda': 'pindah',
#  'bravo': 'hebat',
#  'baro': 'baru',
#  'tidak.sekolah': 'tidak sekolah',
#  'jangan.di': 'jangan di',
#  'mestinya': 'seharusnya',
#  'rata"': 'rata-rata',
#  'kayak': 'seperti',
#  'mulu': 'terus-menerus',
#  'lu,lo': 'kamu',
#  'gua,gue,gw': 'saya',
#  'dum8nta': 'diminta',
#  'buya': 'buat',
#  'biyaya': 'biaya',
#  'daersh': 'daerah',
#  'adlh': 'adalah',
#  'mis:': 'misalnya',
#  'p.': 'pulau',
#  'Benerrrrrr': 'benar',
#  'lainya': 'lainnya',
#  'wowo': 'prabowo',
#  'bp': 'bapak',
#  'pelosk2': 'pelosok-pelosok',
#  'sya': 'saya',
#  'betulkan': 'membenarkan',
#  'sangat2': 'benar-benar',
#  'aza': 'saja',
#  'guru2': 'guru-guru',
#  'daera': 'daerah',
#  'sampek': 'sampai',
#  'narsum': 'narasumber',
#  'broadingschool': 'sekolah asrama',
#  'DP': 'uang muka',
#  'jta': 'juta',
#  'drmana': 'dari mana',
#  'efesiensi': 'efisiensi',
#  'contektual': 'kontekstual',
#  'trima': 'terima',
#  'sma': 'sama',
#  'bgtu': 'begitu',
#  'bgt2': 'banget-banget',
#  'kmrn': 'kemarin',
#  'krna': 'karena',
#  'bbrp': 'beberapa',
#  'mntp': 'mantap',
#  'mntap': 'mantap',
#  'mantul': 'mantap betul',
#  'btw': 'ngomong-ngomong',
#  'loh': 'lho',
#  'lho': 'lho',
#  'deh': 'saja',
#  'sih': 'memang',
#  'kok': 'mengapa',
#  'ya': 'iya',
#  'jgk': 'juga',
#  'ajaib': 'aneh',
#  'pgn': 'pengen',
#  'pengen': 'ingin',
#  'blom': 'belum',
#  'mntk': 'minta',
#  'ntr': 'nanti',
#  'ntr2': 'nantinya',
#  'tmn': 'teman',
#  'temen': 'teman',
#  'lgsg': 'langsung',
#  'dikit': 'sedikit',
#  'td': 'tadi',
#  'trs2': 'terus-terusan',
#  'thx': 'terima kasih',
#  'makasih': 'terima kasih',
#  'tq': 'terima kasih',
#  'pls2': 'tolong-tolong',
#  'sumpah': 'sungguh',
#  'parah': 'buruk sekali',
#  'emg': 'memang',
#  'dlsb': 'dan lain sebagainya',
#  'keb': 'kebutuhan',
#  'hnya': 'hanya',
#  'tlong': 'tolong',
#  'dlam': 'dalam',
#  'ngakak': 'tertawa',
#  'hsl': 'hasil',
#  'orgtuanya': 'orang tuanya',
#  'hukumnyauu': 'hukumnya',
#  'betul': 'benar',
#  'mudah2an': 'mudah-mudahan',
#  'kptsan': 'keputusan',
#  'mningkatkn': 'meningkatkan',
#  'bwh': 'bawah',
#  'mndptkn': 'mendapatkan',
#  'pmddkn': 'Pendidikan',
#  'lyk': 'layak',
#  'tetep': 'tetap',
#  'nich': 'nih',
#  'gatiskan': 'gratiskan',
#  'kmi': 'kami',
#  'jebol': 'bolong',
#  'grtis': 'gratis',
#  'suasta': 'swasta',
#  'mngkn': 'mungkin',
#  'emng': 'emang',
#  'haturnuhun': 'terima kasih',
#  'jgn2': 'jangan-jangan',
#  'bgun': 'bangun',
#  'omonv': 'omong',
#  'bonafit': 'keuntungan',
#  'tspu': 'tapi',
#  'tttp': 'tetap',
#  'progam': 'program',
#  'bansos': 'bantuan sosial',
#  'jangan\\"': 'jangan-jangan',
#  'ama': 'sama',
#  'kgk': 'tidak',
#  'bukannya': 'bukan',
#  'inilah': 'ini lah',
#  'itulah': 'itu lah',
#  'infa': 'infak',
#  'komitelah': 'komite lah',
#  'semata mata': 'semata-mata',
#  'Bln': 'bulan',
#  'smp': 'SMP',
#  'Lks': 'lembar kerja siswa',
#  'pngembangan': 'pengembangan',
#  'qurban': 'kurban',
#  'dftr': 'daftar',
#  'Dll': 'dan lain-lain',
#  'sedihhh': 'sedih',
#  'nkri': 'Negara Kesatuan Republik Indonesia',
#  'Smoga': 'semoga',
#  'inilh': 'ini lah',
#  'itulh': 'itu lah',
#  'sht': 'sehat',
#  'graris': 'gratis',
#  'Mending': 'lebih baik',
#  'sja': 'saja',
#  'tiadakan': 'hapuskan',
#  'kedudukannya': 'kedudukan mereka',
#  'basi': 'tidak relevan',
#  'boong': 'bohong',
#  'KEPSEK': 'kepala sekolah',
#  'sekollah': 'sekolah',
#  'wali murid': 'orang tua siswa',
#  'KONOHA': 'indonesia',
#  'Dibali': 'dibalik',
#  'paud': 'Pendidikan Anak Usia Dini',
#  'CUAN': 'keuntungan',
#  'omon-omon': 'omong-omong',
#  'efisiensi': 'penghematan',
#  'pembwa': 'pembawa',
#  'apak': 'apa',
#  'klau': 'kalau',
#  'wujudkan': 'mewujudkan',
#  'omongan': 'perkataan',
#  'y': 'yang',
#  'mngkin': 'mungkin',
#  'dftrnya': 'daftarnya',
#  'tmbus': 'tembus',
#  'tilep': 'menggelapkan',
#  'bossss': 'bos',
#  'rezekinya': 'rezekinya',
#  'bangun': 'membangun',
#  'terealisasi': 'terwujud',
#  'Yessss': 'ya',
#  'ahhhhh': 'ah',
#  'buat': 'untuk',
#  'kebawah': 'ke bawah',
#  'tak': 'tidak',
#  'kocak': 'lucu',
#  'di rezim': 'pada masa pemerintahan',
#  'SMA': 'Sekolah Menengah Atas',
#  'SMAS': 'Sekolah Menengah Atas Swasta',
#  'tk': 'Taman Kanak-Kanak',
#  'mi': 'Madrasah Ibtidaiyah',
#  'smpit': 'Sekolah Menengah Pertama Islam Terpadu',
#  'sdit': 'Sekolah Dasar Islam Terpadu',
#  'MTS': 'Madrasah Tsanawiyah',
#  'dibuhkan': 'dibutuhkan',
#  'kebutuha': 'kebutuhan',
#  'sesangkang': 'sekarang ini',
#  'uu': 'undang-undang',
#  'uud': 'undang-undang dasar',
#  'bulannyanyg': 'bulannya yang',
#  'paten': 'bagus',
#  'beresiko': 'berisiko',
#  'blum': 'belum',
#  'guru2nya': 'guru-gurunya',
#  'belahar': 'belajar',
#  'Tttttapi': 'tapi',
#  'pnt': 'penting',
#  'mkn': 'makan',
#  'mbiayai': 'membiayai',
#  'gembel': 'miskin',
#  'brbndog2': 'berbondong-bondong',
#  'dadar': 'dasar',
#  'gedhe': 'besar',
#  'swst': 'swasta',
#  'boncos': 'bangkrut',
#  'tunjab': 'tunjangan jabatan',
#  'tunkin': 'tunjangan kinerja',
#  'ndasmu': 'kepalamu',
#  'perdin': 'perjalanan dinas',
#  'pjbt': 'pejabat',
#  'bersaingdgn': 'bersaing dengan',
#  'azaz': 'atas',
#  ...}

# %%
import re
# Melakukan penanganan slang/singkatan
def replace_slang(text,dict_slang):
    # Mengganti frasa menggunakan regex
    for slang, pengganti in dict_slang.items():
        text = re.sub(r'\b' + re.escape(slang) + r'\b', pengganti, text) # versi tanpa ignorecase, sensitif dengan huruf kapital atau kecil
    return text

# %%
df['new'] = df['text'].apply(lambda x: replace_slang(x, data))

# %%
df
# Out:
#                                                    text sentiment  \
# 0     MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral
# 1     Komisi X DPR RI berkomitmen mengawal implement...   neutral
# 2     MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...   neutral
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral
# ...                                                 ...       ...
# 5361       Bagus itu gak semuanya org punya uang semoga  negative
# 5362  Nanti ukungnya di korop kalao semua di bebanka...  negative
# 5363  Hampang sj! Dana MBG alihkan sepenuhnya ke bia...  negative
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...   neutral
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...  negative
#
#                     username          created_at  likes  reply_count  \
# 0                        NaN 2025-05-30 04:22:59    1.0            0
# 1                        NaN 2025-05-30 04:19:07    0.0            0
# 2                        NaN 2025-05-30 04:11:28    3.0            2
# 3                        NaN 2025-05-30 04:03:08    3.0            0
# 4                        NaN 2025-05-30 03:50:46    0.0            0
# ...                      ...                 ...    ...          ...
# 5361     @ArdhiROBLOXCHANNEL 2025-05-30 02:37:07    0.0            0
# 5362            @hambali8442 2025-05-30 02:36:47    0.0            0
# 5363  @muhamadsmithwayne6496 2025-05-30 02:32:14    0.0            0
# 5364        @TimPublikasiFHO 2025-05-30 02:30:08    1.0            1
# 5365           @dinadidik641 2025-05-30 03:24:09    0.0            0
#
#                                                     url  sentiment_num  \
# 0     https://x.com/undefined/status/192830611885126...            2.0
# 1     https://x.com/undefined/status/192830514333582...            2.0
# 2     https://x.com/undefined/status/192830322054963...            2.0
# 3     https://x.com/undefined/status/192830112260070...            2.0
# 4     https://x.com/undefined/status/192829801043108...            2.0
# ...                                                 ...            ...
# 5361                                                NaN            3.0
# 5362                                                NaN            3.0
# 5363                                                NaN            3.0
# 5364                                                NaN            2.0
# 5365                                                NaN            3.0
#
#                                                     new
# 0     MK Putuskan Sekolah Dasar-Sekolah Menengah Per...
# 1     Komisi X DPR RI berkomitmen mengawal implement...
# 2     MK Putuskan Sekolah Dasar-Sekolah Menengah Ata...
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...
# ...                                                 ...
# 5361   Bagus itu tidak semuanya orang punya uang semoga
# 5362  Nanti ukungnya di korop kalao semua di bebanka...
# 5363  Hampang saja! Dana Makan Bergizi Gratis alihka...
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...
#
# [5366 rows x 9 columns]

# %% [markdown]
# #Normalisasi

# %%
def remove_URL(tweet): # Menghapus URL
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', tweet)

def remove_html(tweet): # Menghapus tag HTML
    html = re.compile(r'<.*?>')
    return html.sub(r'', tweet)

def remove_emoji(tweet): # Menghapus emoji
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"
        u"\U0001F300-\U0001F5FF"
        u"\U0001F680-\U0001F6FF"
        u"\U0001F1E0-\U0001F1FF"
                            "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', tweet)

def remove_username(tweet): # Menghapus username
    username_pattern = re.compile(r'@\w+')
    return username_pattern.sub(r'', tweet)

def remove_numbers (tweet): # Menghapus angka
    tweet = re.sub(r'\d+', '', tweet)
    return tweet

def remove_symbols (tweet): # Menghapus simbol
    tweet = re.sub(r'[^a-zA-Z0-9\s]', '', tweet)
    return tweet

def case_folding(text): # Mengubah huruf yang masih uppercase menjadi lowercase
  if isinstance(text, str):
    lowercase_text = text.lower()
    return lowercase_text
  else:
    return text

# %%
# Visualisasi clean dataset 'full_text'
df['cleaning'] = df['new'].apply(lambda x: remove_URL(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_html(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_emoji(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_username(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_symbols(x))
df['cleaning'] = df['cleaning'].apply(lambda x: remove_numbers(x))
df['cleaning'] = df['cleaning'].apply(lambda x: case_folding(x))

df
# Out:
#                                                    text sentiment  \
# 0     MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral
# 1     Komisi X DPR RI berkomitmen mengawal implement...   neutral
# 2     MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...   neutral
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral
# ...                                                 ...       ...
# 5361       Bagus itu gak semuanya org punya uang semoga  negative
# 5362  Nanti ukungnya di korop kalao semua di bebanka...  negative
# 5363  Hampang sj! Dana MBG alihkan sepenuhnya ke bia...  negative
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...   neutral
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...  negative
#
#                     username          created_at  likes  reply_count  \
# 0                        NaN 2025-05-30 04:22:59    1.0            0
# 1                        NaN 2025-05-30 04:19:07    0.0            0
# 2                        NaN 2025-05-30 04:11:28    3.0            2
# 3                        NaN 2025-05-30 04:03:08    3.0            0
# 4                        NaN 2025-05-30 03:50:46    0.0            0
# ...                      ...                 ...    ...          ...
# 5361     @ArdhiROBLOXCHANNEL 2025-05-30 02:37:07    0.0            0
# 5362            @hambali8442 2025-05-30 02:36:47    0.0            0
# 5363  @muhamadsmithwayne6496 2025-05-30 02:32:14    0.0            0
# 5364        @TimPublikasiFHO 2025-05-30 02:30:08    1.0            1
# 5365           @dinadidik641 2025-05-30 03:24:09    0.0            0
#
#                                                     url  sentiment_num  \
# 0     https://x.com/undefined/status/192830611885126...            2.0
# 1     https://x.com/undefined/status/192830514333582...            2.0
# 2     https://x.com/undefined/status/192830322054963...            2.0
# 3     https://x.com/undefined/status/192830112260070...            2.0
# 4     https://x.com/undefined/status/192829801043108...            2.0
# ...                                                 ...            ...
# 5361                                                NaN            3.0
# 5362                                                NaN            3.0
# 5363                                                NaN            3.0
# 5364                                                NaN            2.0
# 5365                                                NaN            3.0
#
#                                                     new  \
# 0     MK Putuskan Sekolah Dasar-Sekolah Menengah Per...
# 1     Komisi X DPR RI berkomitmen mengawal implement...
# 2     MK Putuskan Sekolah Dasar-Sekolah Menengah Ata...
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...
# ...                                                 ...
# 5361   Bagus itu tidak semuanya orang punya uang semoga
# 5362  Nanti ukungnya di korop kalao semua di bebanka...
# 5363  Hampang saja! Dana Makan Bergizi Gratis alihka...
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...
#
#                                                cleaning
# 0     mk putuskan sekolah dasarsekolah menengah pert...
# 1     komisi x dpr ri berkomitmen mengawal implement...
# 2     mk putuskan sekolah dasarsekolah menengah atas...
# 3     respons wamendagri bima arya soal pendidikan g...
# 4     respons pemkab bantul soal putusan mk tentang ...
# ...                                                 ...
# 5361   bagus itu tidak semuanya orang punya uang semoga
# 5362  nanti ukungnya di korop kalao semua di bebanka...
# 5363  hampang saja dana makan bergizi gratis alihkan...
# 5364  jika apbn tidak dikorupsi   maka sekolah neger...
# 5365  iya jika tidak ada korupsi sekolah negeri berk...
#
# [5366 rows x 10 columns]

# %% [markdown]
# #Stopword

# %%
# !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/eLearning/refs/heads/master/data/stopwords_id.txt
# !wget -P data/ https://raw.githubusercontent.com/louisowen6/NLP_bahasa_resources/master/combined_stop_words.txt
# Out:
# --2025-06-05 08:12:56--  https://raw.githubusercontent.com/taudataanalytics/eLearning/refs/heads/master/data/stopwords_id.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6446 (6.3K) [text/plain]
# Saving to: ‘data/stopwords_id.txt.4’
#
# stopwords_id.txt.4  100%[===================>]   6.29K  --.-KB/s    in 0s
#
# 2025-06-05 08:12:56 (29.2 MB/s) - ‘data/stopwords_id.txt.4’ saved [6446/6446]
#
# --2025-06-05 08:12:56--  https://raw.githubusercontent.com/louisowen6/NLP_bahasa_resources/master/combined_stop_words.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6096 (6.0K) [text/plain]
# Saving to: ‘data/combined_stop_words.txt.4’
#
# combined_stop_words 100%[===================>]   5.95K  --.-KB/s    in 0s
#
# 2025-06-05 08:12:56 (65.0 MB/s) - ‘data/combined_stop_words.txt.4’ saved [6096/6096]

# %%
# Membaca file stopwords
stopword_files = ['data/stopwords_id.txt', 'data/combined_stop_words.txt']
id_stop = []
for stopword_file in stopword_files:
    with open(stopword_file, "r", encoding="utf-8", errors='replace') as file:
        id_stop.extend([word.strip().lower() for word in file.readlines()])


# Bersihkan stopwords (hapus spasi dan ubah ke huruf kecil)
id_stop = [word for word in id_stop if word] # remove empty strings

# %%
# Tambahkan stopwords tambahan
additional_stopwords = {'gk','nggak''aja', 'dong', 'deh', 'nih', 'sih', 'kok', 'kayak', 'makanya', 'nggak',
    'gak', 'ga', 'gue', 'gua', 'lu', 'loe', 'lho', 'ya', 'si', 'dong', 'doang',
    'malah', 'banget', 'nya', 'nyaa', 'nih', 'tuh', 'lah', 'kan', 'pun', 'mah',
    'cuma', 'padahal', 'seharusnya', 'soalnya', 'biar', 'biarpun', 'bakal',
    'bakalan', 'semoga', 'moga', 'mudah2an', 'ntar', 'nanti', 'sama', 'dengan',
    'tanpa', 'dulu', 'lagi', 'terus', 'udah', 'sudah', 'belum', 'baru', 'mau',
    'akan', 'adalah', 'ialah', 'itu', 'ini', 'tersebut', 'tsb', 'anda', 'kamu',
    'saya', 'aku', 'mereka', 'kita', 'kami', 'engkau', 'siapa', 'apa', 'dimana',
    'kenapa', 'mengapa', 'bagaimana', 'yang', 'di', 'ke', 'dari', 'pada', 'buat',
    'untuk', 'agar', 'karena', 'sebab', 'walaupun', 'meskipun', 'hingga', 'sejak',
    'sebelum', 'sesudah', 'tetapi', 'namun', 'dan', 'atau', 'juga', 'kalau',
    'jika', 'bila', 'hingga', 'supaya', 'sehingga', 'oleh', 'tentang', 'terhadap',
    'dalam', 'atas', 'bagi', 'antara', 'selama', 'serta', 'bahwa'}
id_stop.extend(additional_stopwords)  # Gabungkan stopwords tambahan

# Fungsi untuk menghapus stopwords
def remove_custom_stopwords(text):
    words = word_tokenize(text)  # Tokenisasi teks
    return ' '.join([word for word in words if word not in id_stop])

# %%
df['no_stopwords'] = df['cleaning'].apply(remove_custom_stopwords)
df
# Out:
#                                                    text sentiment  \
# 0     MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral
# 1     Komisi X DPR RI berkomitmen mengawal implement...   neutral
# 2     MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...   neutral
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral
# ...                                                 ...       ...
# 5361       Bagus itu gak semuanya org punya uang semoga  negative
# 5362  Nanti ukungnya di korop kalao semua di bebanka...  negative
# 5363  Hampang sj! Dana MBG alihkan sepenuhnya ke bia...  negative
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...   neutral
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...  negative
#
#                     username          created_at  likes  reply_count  \
# 0                        NaN 2025-05-30 04:22:59    1.0            0
# 1                        NaN 2025-05-30 04:19:07    0.0            0
# 2                        NaN 2025-05-30 04:11:28    3.0            2
# 3                        NaN 2025-05-30 04:03:08    3.0            0
# 4                        NaN 2025-05-30 03:50:46    0.0            0
# ...                      ...                 ...    ...          ...
# 5361     @ArdhiROBLOXCHANNEL 2025-05-30 02:37:07    0.0            0
# 5362            @hambali8442 2025-05-30 02:36:47    0.0            0
# 5363  @muhamadsmithwayne6496 2025-05-30 02:32:14    0.0            0
# 5364        @TimPublikasiFHO 2025-05-30 02:30:08    1.0            1
# 5365           @dinadidik641 2025-05-30 03:24:09    0.0            0
#
#                                                     url  sentiment_num  \
# 0     https://x.com/undefined/status/192830611885126...            2.0
# 1     https://x.com/undefined/status/192830514333582...            2.0
# 2     https://x.com/undefined/status/192830322054963...            2.0
# 3     https://x.com/undefined/status/192830112260070...            2.0
# 4     https://x.com/undefined/status/192829801043108...            2.0
# ...                                                 ...            ...
# 5361                                                NaN            3.0
# 5362                                                NaN            3.0
# 5363                                                NaN            3.0
# 5364                                                NaN            2.0
# 5365                                                NaN            3.0
#
#                                                     new  \
# 0     MK Putuskan Sekolah Dasar-Sekolah Menengah Per...
# 1     Komisi X DPR RI berkomitmen mengawal implement...
# 2     MK Putuskan Sekolah Dasar-Sekolah Menengah Ata...
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...
# ...                                                 ...
# 5361   Bagus itu tidak semuanya orang punya uang semoga
# 5362  Nanti ukungnya di korop kalao semua di bebanka...
# 5363  Hampang saja! Dana Makan Bergizi Gratis alihka...
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...
#
#                                                cleaning  \
# 0     mk putuskan sekolah dasarsekolah menengah pert...
# 1     komisi x dpr ri berkomitmen mengawal implement...
# 2     mk putuskan sekolah dasarsekolah menengah atas...
# 3     respons wamendagri bima arya soal pendidikan g...
# 4     respons pemkab bantul soal putusan mk tentang ...
# ...                                                 ...
# 5361   bagus itu tidak semuanya orang punya uang semoga
# 5362  nanti ukungnya di korop kalao semua di bebanka...
# 5363  hampang saja dana makan bergizi gratis alihkan...
# 5364  jika apbn tidak dikorupsi   maka sekolah neger...
# 5365  iya jika tidak ada korupsi sekolah negeri berk...
#
#                                            no_stopwords
# 0     mk putuskan sekolah dasarsekolah menengah swas...
# 1     komisi x dpr ri berkomitmen mengawal implement...
# 2     mk putuskan sekolah dasarsekolah menengah nege...
# 3     respons wamendagri bima arya pendidikan gratis...
# 4     respons pemkab bantul putusan mk sekolah grati...
# ...                                                 ...
# 5361                                         bagus uang
# 5362  ukungnya korop kalao bebankan pemerintah danan...
# 5363  hampang dana makan bergizi gratis alihkan sepe...
# 5364        apbn dikorupsi sekolah negeri swasta gratis
# 5365  iya korupsi sekolah negeri berkualitas mencuku...
#
# [5366 rows x 11 columns]

# %% [markdown]
# #Lemmatization

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
kata_dasar = [
    'setuju', 'sukses', 'terbaik', 'pemerataan', 'lingkungan', 'setara', 'alasan',
    'pendidikan', 'peserta', 'impian', 'kejuruan', 'menteri', 'terapkan', 'perdebatan',
    'hilangkan', 'biarkan','kualitas', 'akses', 'program', 'pengembangan', 'pemerintah', 'dukungan', 'kebijakan',
    'pelayanan', 'pemberdayaan', 'pelajar', 'guru', 'inovasi', 'fasilitas', 'pembelajaran',
    'kebutuhan', 'pelatihan', 'partisipasi', 'evaluasi', 'pelaksanaan', 'keadilan',
    'motivasi', 'hasil', 'pendampingan', 'pengawasan', 'pengelolaan', 'standar',
    'pengaruh', 'peran', 'kesempatan', 'tantangan', 'penguatan', 'kolaborasi', 'solusi',
    'transparansi', 'akreditasi', 'komitmen', 'perbaikan', 'kepemimpinan'
]

# %%
# Fungsi stemming dengan perlindungan kata dasar
def stem_text(text):
    words = text.split()
    stemmed_words = []
    for word in words:
        stemmed = stemmer.stem(word)
        # Jika kata asli ada di kata_dasar, gunakan kata asli
        if word in kata_dasar:
            stemmed_words.append(word)
        # Jika hasil stemming malah menghapus bentuk dasar yang kamu inginkan
        elif stemmed in kata_dasar:
            stemmed_words.append(stemmed)
        else:
            stemmed_words.append(stemmed)
    return ' '.join(stemmed_words)

# %%
df['stemmed_text'] = df['no_stopwords'].apply(stem_text)

# %%
df
# Out:
#                                                    text sentiment  \
# 0     MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral
# 1     Komisi X DPR RI berkomitmen mengawal implement...   neutral
# 2     MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...   neutral
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral
# ...                                                 ...       ...
# 5361       Bagus itu gak semuanya org punya uang semoga  negative
# 5362  Nanti ukungnya di korop kalao semua di bebanka...  negative
# 5363  Hampang sj! Dana MBG alihkan sepenuhnya ke bia...  negative
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...   neutral
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...  negative
#
#                     username          created_at  likes  reply_count  \
# 0                        NaN 2025-05-30 04:22:59    1.0            0
# 1                        NaN 2025-05-30 04:19:07    0.0            0
# 2                        NaN 2025-05-30 04:11:28    3.0            2
# 3                        NaN 2025-05-30 04:03:08    3.0            0
# 4                        NaN 2025-05-30 03:50:46    0.0            0
# ...                      ...                 ...    ...          ...
# 5361     @ArdhiROBLOXCHANNEL 2025-05-30 02:37:07    0.0            0
# 5362            @hambali8442 2025-05-30 02:36:47    0.0            0
# 5363  @muhamadsmithwayne6496 2025-05-30 02:32:14    0.0            0
# 5364        @TimPublikasiFHO 2025-05-30 02:30:08    1.0            1
# 5365           @dinadidik641 2025-05-30 03:24:09    0.0            0
#
#                                                     url  sentiment_num  \
# 0     https://x.com/undefined/status/192830611885126...            2.0
# 1     https://x.com/undefined/status/192830514333582...            2.0
# 2     https://x.com/undefined/status/192830322054963...            2.0
# 3     https://x.com/undefined/status/192830112260070...            2.0
# 4     https://x.com/undefined/status/192829801043108...            2.0
# ...                                                 ...            ...
# 5361                                                NaN            3.0
# 5362                                                NaN            3.0
# 5363                                                NaN            3.0
# 5364                                                NaN            2.0
# 5365                                                NaN            3.0
#
#                                                     new  \
# 0     MK Putuskan Sekolah Dasar-Sekolah Menengah Per...
# 1     Komisi X DPR RI berkomitmen mengawal implement...
# 2     MK Putuskan Sekolah Dasar-Sekolah Menengah Ata...
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...
# ...                                                 ...
# 5361   Bagus itu tidak semuanya orang punya uang semoga
# 5362  Nanti ukungnya di korop kalao semua di bebanka...
# 5363  Hampang saja! Dana Makan Bergizi Gratis alihka...
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...
#
#                                                cleaning  \
# 0     mk putuskan sekolah dasarsekolah menengah pert...
# 1     komisi x dpr ri berkomitmen mengawal implement...
# 2     mk putuskan sekolah dasarsekolah menengah atas...
# 3     respons wamendagri bima arya soal pendidikan g...
# 4     respons pemkab bantul soal putusan mk tentang ...
# ...                                                 ...
# 5361   bagus itu tidak semuanya orang punya uang semoga
# 5362  nanti ukungnya di korop kalao semua di bebanka...
# 5363  hampang saja dana makan bergizi gratis alihkan...
# 5364  jika apbn tidak dikorupsi   maka sekolah neger...
# 5365  iya jika tidak ada korupsi sekolah negeri berk...
#
#                                            no_stopwords  \
# 0     mk putuskan sekolah dasarsekolah menengah swas...
# 1     komisi x dpr ri berkomitmen mengawal implement...
# 2     mk putuskan sekolah dasarsekolah menengah nege...
# 3     respons wamendagri bima arya pendidikan gratis...
# 4     respons pemkab bantul putusan mk sekolah grati...
# ...                                                 ...
# 5361                                         bagus uang
# 5362  ukungnya korop kalao bebankan pemerintah danan...
# 5363  hampang dana makan bergizi gratis alihkan sepe...
# 5364        apbn dikorupsi sekolah negeri swasta gratis
# 5365  iya korupsi sekolah negeri berkualitas mencuku...
#
#                                            stemmed_text
# 0     mk putus sekolah dasarsekolah tengah swasta gr...
# 1     komisi x dpr ri komitmen awal implementasi put...
# 2     mk putus sekolah dasarsekolah tengah negeri sw...
# 3     respons wamendagri bima arya pendidikan gratis...
# 4     respons pemkab bantul putus mk sekolah gratis ...
# ...                                                 ...
# 5361                                         bagus uang
# 5362  ukungnya korop kalao beban pemerintah dana atu...
# 5363  hampang dana makan gizi gratis alih sepenuh bi...
# 5364          apbn korupsi sekolah negeri swasta gratis
# 5365  iya korupsi sekolah negeri kualitas cukup butu...
#
# [5366 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5366 entries, 0 to 5365
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   text           5366 non-null   object
#  1   sentiment      5361 non-null   object
#  2   username       3699 non-null   object
#  3   created_at     5366 non-null   datetime64[ns]
#  4   likes          5366 non-null   float64
#  5   reply_count    5366 non-null   int64
#  6   url            1667 non-null   object
#  7   sentiment_num  4507 non-null   float64
#  8   new            5366 non-null   object
#  9   cleaning       5366 non-null   object
#  10  no_stopwords   5366 non-null   object
#  11  stemmed_text   5366 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 503.2+ KB

# %%
df.to_csv("hasil prepro data fix.csv", index=False)

# %% [markdown]
# #Visualisasi

# %%
# Import data yang telah di ekspor
import pandas as pd

url = "https://raw.githubusercontent.com/Nadira173/DATA_AMS/main/hasil%20prepro%20data%20fix%20(3).csv"

try:
    df_final = pd.read_csv(url)
    print(df_final.head())
except Exception as e:
    print("Terjadi kesalahan saat membaca file:", e)
# Out:
#                                                 text sentiment username  \
# 0  MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral      NaN
# 1  Komisi X DPR RI berkomitmen mengawal implement...   neutral      NaN
# 2  MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral      NaN
# 3  Respons Wamendagri Bima Arya soal Pendidikan G...   neutral      NaN
# 4  Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral      NaN
#
#             created_at  likes  reply_count  \
# 0  2025-05-30 04:22:59    1.0            0
# 1  2025-05-30 04:19:07    0.0            0
# 2  2025-05-30 04:11:28    3.0            2
# 3  2025-05-30 04:03:08    3.0            0
# 4  2025-05-30 03:50:46    0.0            0
#
#                                                  url  sentiment_num  \
# 0  https://x.com/undefined/status/192830611885126...            2.0
# 1  https://x.com/undefined/status/192830514333582...            2.0
# 2  https://x.com/undefined/status/192830322054963...            2.0
# 3  https://x.com/undefined/status/192830112260070...            2.0
# 4  https://x.com/undefined/status/192829801043108...            2.0
#
#                                                  new  \
# 0  MK Putuskan Sekolah Dasar-Sekolah Menengah Per...
# 1  Komisi X DPR RI berkomitmen mengawal implement...
# 2  MK Putuskan Sekolah Dasar-Sekolah Menengah Ata...
# 3  Respons Wamendagri Bima Arya soal Pendidikan G...
# 4  Respons Pemkab Bantul Soal Putusan MK tentang ...
#
#                                             cleaning  \
# 0  mk putuskan sekolah dasarsekolah menengah pert...
# 1  komisi x dpr ri berkomitmen mengawal implement...
# 2  mk putuskan sekolah dasarsekolah menengah atas...
# 3  respons wamendagri bima arya soal pendidikan g...
# 4  respons pemkab bantul soal putusan mk tentang ...
#
#                                         no_stopwords  \
# 0  mk putuskan sekolah dasarsekolah menengah swas...
# 1  komisi x dpr ri berkomitmen mengawal implement...
# 2  mk putuskan sekolah dasarsekolah menengah nege...
# 3  respons wamendagri bima arya pendidikan gratis...
# 4  respons pemkab bantul putusan mk sekolah grati...
#
#                                         stemmed_text
# 0  mk putus sekolah dasarsekolah tengah swasta gr...
# 1  komisi x dpr ri komitmen awal implementasi put...
# 2  mk putus sekolah dasarsekolah tengah negeri sw...
# 3  respons wamendagri bima arya pendidikan gratis...
# 4  respons pemkab bantul putus mk sekolah gratis ...

# %%
df_final = df_final.drop('sentiment_num', axis=1)
print(df_final.head())
# Out:
#                                                 text sentiment username  \
# 0  MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral      NaN
# 1  Komisi X DPR RI berkomitmen mengawal implement...   neutral      NaN
# 2  MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral      NaN
# 3  Respons Wamendagri Bima Arya soal Pendidikan G...   neutral      NaN
# 4  Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral      NaN
#
#             created_at  likes  reply_count  \
# 0  2025-05-30 04:22:59    1.0            0
# 1  2025-05-30 04:19:07    0.0            0
# 2  2025-05-30 04:11:28    3.0            2
# 3  2025-05-30 04:03:08    3.0            0
# 4  2025-05-30 03:50:46    0.0            0
#
#                                                  url  \
# 0  https://x.com/undefined/status/192830611885126...
# 1  https://x.com/undefined/status/192830514333582...
# 2  https://x.com/undefined/status/192830322054963...
# 3  https://x.com/undefined/status/192830112260070...
# 4  https://x.com/undefined/status/192829801043108...
#
#                                                  new  \
# 0  MK Putuskan Sekolah Dasar-Sekolah Menengah Per...
# 1  Komisi X DPR RI berkomitmen mengawal implement...
# 2  MK Putuskan Sekolah Dasar-Sekolah Menengah Ata...
# 3  Respons Wamendagri Bima Arya soal Pendidikan G...
# 4  Respons Pemkab Bantul Soal Putusan MK tentang ...
#
#                                             cleaning  \
# 0  mk putuskan sekolah dasarsekolah menengah pert...
# 1  komisi x dpr ri berkomitmen mengawal implement...
# 2  mk putuskan sekolah dasarsekolah menengah atas...
# 3  respons wamendagri bima arya soal pendidikan g...
# 4  respons pemkab bantul soal putusan mk tentang ...
#
#                                         no_stopwords  \
# 0  mk putuskan sekolah dasarsekolah menengah swas...
# 1  komisi x dpr ri berkomitmen mengawal implement...
# 2  mk putuskan sekolah dasarsekolah menengah nege...
# 3  respons wamendagri bima arya pendidikan gratis...
# 4  respons pemkab bantul putusan mk sekolah grati...
#
#                                         stemmed_text
# 0  mk putus sekolah dasarsekolah tengah swasta gr...
# 1  komisi x dpr ri komitmen awal implementasi put...
# 2  mk putus sekolah dasarsekolah tengah negeri sw...
# 3  respons wamendagri bima arya pendidikan gratis...
# 4  respons pemkab bantul putus mk sekolah gratis ...

# %%
df_youtube = df_final[df_final['url'].isnull()]
df_youtube
# Out:
#                                                    text sentiment  \
# 1667               Apakah smp di bantul jogja jg gratis   neutral
# 1668  Wah makin ngeri aja nih. Udah bener swasta ber...  negative
# 1669                  Kalau swasta siapa yg byr gurunya  negative
# 1670  Tidak setuju. Biarkan anak2 dr keluarga mampu ...  negative
# 1671      Cuma Teori ... Praktek nya tetap ada pungutan  negative
# ...                                                 ...       ...
# 5361       Bagus itu gak semuanya org punya uang semoga  negative
# 5362  Nanti ukungnya di korop kalao semua di bebanka...  negative
# 5363  Hampang sj! Dana MBG alihkan sepenuhnya ke bia...  negative
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...   neutral
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...  negative
#
#                     username           created_at  likes  reply_count  url  \
# 1667       @ZahraniPutri-u1d  2025-05-28 11:15:32    0.0            0  NaN
# 1668     @AlifiaMinawati-k9i  2025-05-28 10:29:30    0.0            0  NaN
# 1669   @hermawanpurwanto6187  2025-05-28 10:12:59    0.0            0  NaN
# 1670       @tanpanamaaja2364  2025-05-28 10:09:39    0.0            0  NaN
# 1671           @iwanpapae690  2025-05-28 09:45:53    0.0            0  NaN
# ...                      ...                  ...    ...          ...  ...
# 5361     @ArdhiROBLOXCHANNEL  2025-05-30 02:37:07    0.0            0  NaN
# 5362            @hambali8442  2025-05-30 02:36:47    0.0            0  NaN
# 5363  @muhamadsmithwayne6496  2025-05-30 02:32:14    0.0            0  NaN
# 5364        @TimPublikasiFHO  2025-05-30 02:30:08    1.0            1  NaN
# 5365           @dinadidik641  2025-05-30 03:24:09    0.0            0  NaN
#
#                                                     new  \
# 1667             Apakah SMP di bantul jogja juga gratis
# 1668  Wah makin mengerikan saja ini. Udah benar swas...
# 1669              Kalau swasta siapa yang bayar gurunya
# 1670  Tidak setuju. Biarkan anak-anak dari keluarga ...
# 1671      Cuma Teori ... Praktek nya tetap ada pungutan
# ...                                                 ...
# 5361   Bagus itu tidak semuanya orang punya uang semoga
# 5362  Nanti ukungnya di korop kalao semua di bebanka...
# 5363  Hampang saja! Dana Makan Bergizi Gratis alihka...
# 5364  jika APBN TIDAK DIKORUPSI ,  maka sekolah Nege...
# 5365  Iya. Jika tidak ada korupsi.... sekolah negeri...
#
#                                                cleaning  \
# 1667             apakah smp di bantul jogja juga gratis
# 1668  wah makin mengerikan saja ini udah benar swast...
# 1669              kalau swasta siapa yang bayar gurunya
# 1670  tidak setuju biarkan anakanak dari keluarga ma...
# 1671         cuma teori  praktek nya tetap ada pungutan
# ...                                                 ...
# 5361   bagus itu tidak semuanya orang punya uang semoga
# 5362  nanti ukungnya di korop kalao semua di bebanka...
# 5363  hampang saja dana makan bergizi gratis alihkan...
# 5364  jika apbn tidak dikorupsi   maka sekolah neger...
# 5365  iya jika tidak ada korupsi sekolah negeri berk...
#
#                                            no_stopwords  \
# 1667                            smp bantul jogja gratis
# 1668  mengerikan swasta berbayar kualitasnya sebobro...
# 1669                               swasta bayar gurunya
# 1670  setuju biarkan anakanak keluarga bersekolah an...
# 1671                             teori praktek pungutan
# ...                                                 ...
# 5361                                         bagus uang
# 5362  ukungnya korop kalao bebankan pemerintah danan...
# 5363  hampang dana makan bergizi gratis alihkan sepe...
# 5364        apbn dikorupsi sekolah negeri swasta gratis
# 5365  iya korupsi sekolah negeri berkualitas mencuku...
#
#                                            stemmed_text
# 1667                            smp bantul jogja gratis
# 1668           keri swasta bayar kualitas bobrok negeri
# 1669                                  swasta bayar guru
# 1670  setuju biarkan anakanak keluarga sekolah anak ...
# 1671                               teori praktek pungut
# ...                                                 ...
# 5361                                         bagus uang
# 5362  ukungnya korop kalao beban pemerintah dana atu...
# 5363  hampang dana makan gizi gratis alih sepenuh bi...
# 5364          apbn korupsi sekolah negeri swasta gratis
# 5365  iya korupsi sekolah negeri kualitas cukup butu...
#
# [3699 rows x 11 columns]

# %%
df_tweet = df_final[df_final['url'].notnull()]
df_tweet
# Out:
#                                                    text sentiment username  \
# 0     MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral      NaN
# 1     Komisi X DPR RI berkomitmen mengawal implement...   neutral      NaN
# 2     MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral      NaN
# 3     Respons Wamendagri Bima Arya soal Pendidikan G...   neutral      NaN
# 4     Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral      NaN
# ...                                                 ...       ...      ...
# 1662  TOK.. TOK... TOK.. MK Tegaskan Negara Wajib Bi...   neutral      NaN
# 1663  Breaking News: MK putuskan SD-SMP negeri dan s...   neutral      NaN
# 1664  MK Putuskan Sekolah Dasar Swasta Tak Boleh Pun...   neutral      NaN
# 1665  Putusan lengkap MK negara harus gratiskan pend...   neutral      NaN
# 1666  MK: Negara harus gratiskan pendidikan dasar di...   neutral      NaN
#
#                created_at  likes  reply_count  \
# 0     2025-05-30 04:22:59  1.000            0
# 1     2025-05-30 04:19:07  0.000            0
# 2     2025-05-30 04:11:28  3.000            2
# 3     2025-05-30 04:03:08  3.000            0
# 4     2025-05-30 03:50:46  0.000            0
# ...                   ...    ...          ...
# 1662  2025-05-27 10:29:53  0.000            1
# 1663  2025-05-27 10:21:50  4.755          737
# 1664  2025-05-27 10:04:06  1.000            0
# 1665  2025-05-27 09:30:29  1.000            0


# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_sorted = df_final.sort_values(by='engagement', ascending=False)

# Ambil 10 tweet teratas
top_n = 10
df_final_top = df_final_sorted.head(top_n)

# Tampilkan index tweet teratas, sudah urut dari tertinggi
print("Index 10 tweet dengan engagement tertinggi (urut dari terbanyak):")
print(df_final_top.index.tolist())

# Buat bar plot dengan urutan dari engagement tertinggi ke terendah
plt.figure(figsize=(12, 6))
sns.barplot(x=df_final_top.index, y='engagement', data=df_final_top,
            palette='viridis', order=df_final_top.index)
plt.title(f'Top {top_n} Tweets by Engagement (Descending)')
plt.xlabel('Tweet Index')
plt.ylabel('Total Engagement (Replies + Likes)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Index 10 tweet dengan engagement tertinggi (urut dari terbanyak):
# [1647, 1345, 1340, 422, 168, 1408, 1663, 1323, 431, 1582]
# <ipython-input-7-305135443f79>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_final_top.index, y='engagement', data=df_final_top,

# %%
# Simpan index tweet teratas ke variabel
top_indices = df_final_top.index.tolist()

# Ambil full_text dan tweet_url berdasarkan index
list_text = list(df_final.loc[top_indices, 'text'])
list_url = list(df_final.loc[top_indices, 'url'])

# Tampilkan hasil seperti format yang diinginkan
for i in range(len(list_text)):
    print(f"{i+1}. Link [{list_url[i]}] : {list_text[i]}")
# Out:
# 1. Link [https://x.com/undefined/status/1927394367938937280] : Mahkamah Konstitusi (MK) memutuskan perkara Nomor 3/PUU-XXII/2024 terkait pengujian Undang-Undang Nomor 20 Tahun 2003 tentang Sistem Pendidikan Nasional (UU Sisdiknas). MK memvonis bahwa pendidikan dasar 9 tahun baik negeri maupun swasta harus digratiskan. Merujuk situs https://t.co/tOl2OlJ9v5
# 2. Link [https://x.com/undefined/status/1927685329298886985] : @kegblgnunfaedh swasta gratis? no thanks apapun yg gratis ga akan ada yg hasilnya bagus gw tetep pilih sekolah yg berbayar biar klo ada yg ga sesuai ama kualitas pendidikan anak gw gw bisa protes kalo gratisan? pffttt
# 3. Link [https://x.com/undefined/status/1927693319213051995] : @kompascom Klo negeri gajadi masalah klo swasta menurutku keliru. Kalo swasta kan murni 100% dari SPP dan uang masuk bukan dibayarin negara. Paling banter ya subsidi 50% sekolah swasta.
# 4. Link [https://x.com/undefined/status/1927343322445607297] : Tok! MK Perintahkan Pemerintah Gratiskan Pendidikan SD-SMP Baik di Sekolah Negeri Maupun Swasta https://t.co/i4QogBFrbu
# 5. Link [https://x.com/undefined/status/1927309261756838247] : Breaking News: MK putuskan SD-SMP negeri dan swasta digratiskan. Kalau ini benar luar biasa sekali. Jauh lebih keren dan berdampak daripada sekadar program makan gratis.. @officialMKRI #PendidikanGratis #PutusanMK #SekolahUntukSemua https://t.co/I9HfIrG0Wb
# 6. Link [https://x.com/undefined/status/1927309261756838247] : Breaking News: MK putuskan SD-SMP negeri dan swasta digratiskan. Kalau ini benar luar biasa sekali. Jauh lebih keren dan berdampak daripada sekadar program makan gratis.. @officialMKRI #PendidikanGratis #PutusanMK #SekolahUntukSemua https://t.co/I9HfIrG0Wb
# 1582  https://x.com/undefined/status/192767317705408...
#
#                                                     new  \
# 1647  Mahkamah Konstitusi (MK) memutuskan perkara No...
# 1345  @kegblgnunfaedh swasta gratis? no thanks apapu...
# 1340  @kompascom Klo negeri gajadi masalah kalau swa...
# 422   Ketok! MK Perintahkan Pemerintah Gratiskan Pen...
# 168   Breaking News: MK putuskan Sekolah Dasar-Sekol...
# 1408  Breaking News: MK putuskan Sekolah Dasar-Sekol...
# 1663  Breaking News: MK putuskan Sekolah Dasar-Sekol...
# 1323  @BudiBukanIntel Bagus memang tapi prakteknya s...
# 431   Unpopular Opinion: (Sebenernya tidak unpopular...
# 1582  Mahkamah Konstitusi (MK) memutuskan perkara No...
#
#                                                cleaning  \
# 1647  mahkamah konstitusi mk memutuskan perkara nomo...
# 1345   swasta gratis no thanks apapun yang gratis ti...
# 1340   klo negeri gajadi masalah kalau swasta menuru...
# 422   ketok mk perintahkan pemerintah gratiskan pend...
# 168   breaking news mk putuskan sekolah dasarsekolah...
# 1408  breaking news mk putuskan sekolah dasarsekolah...
# 1663  breaking news mk putuskan sekolah dasarsekolah...
# 1323   bagus memang tapi prakteknya sptnya susah swa...
# 431   unpopular opinion sebenernya tidak unpopular j...
# 1582  mahkamah konstitusi mk memutuskan perkara nomo...
#
#                                            no_stopwords  \
# 1647  mahkamah konstitusi mk memutuskan perkara nomo...
# 1345  swasta gratis thanks apapun gratis hasilnya ba...
# 1340  klo negeri gajadi swasta menurutku keliru kalo...
# 422   ketok mk perintahkan pemerintah gratiskan pend...
# 168   breaking news mk putuskan sekolah dasarsekolah...
# 1408  breaking news mk putuskan sekolah dasarsekolah...
# 1663  breaking news mk putuskan sekolah dasarsekolah...
# 1323  bagus prakteknya sptnya susah swasta mahal for...
# 431   unpopular opinion sebenernya unpopular sekolah...
# 1582  mahkamah konstitusi mk memutuskan perkara nomo...
#
#                                            stemmed_text  engagement
# 1647  mahkamah konstitusi mk putus perkara nomor puu...    1080.000
# 1345  swasta gratis thanks apa gratis hasil bagus pi...     809.000
# 1340  klo negeri gajadi swasta turut keliru kalo swa...     772.000
# 422   ketok mk perintah pemerintah gratis pendidikan...     760.000
# 168   breaking news mk putus sekolah dasarsekolah te...     742.754
# 1408  breaking news mk putus sekolah dasarsekolah te...     741.756
# 1663  breaking news mk putus sekolah dasarsekolah te...     741.755
# 1323  bagus praktek sptnya susah swasta mahal for a ...     569.000
# 431   unpopular opinion sebenernya unpopular sekolah...     429.000
# 1582  mahkamah konstitusi mk putus perkara nomor puu...     407.803

# %% [markdown]
# ###Interpretasi
# Tweet dengan engagement tertinggi didominasi oleh berita (netral) dan respons negatif, mencerminkan kekhawatiran publik terhadap implementasi pendidikan gratis.

# %% [markdown]
# #Distribusi Sentimen

# %% [markdown]
# ##Distribusi sentimen gabungan (twitter dan youtube)

# %%
import matplotlib.pyplot as plt

# Hitung distribusi dan ubah index-nya ke label sentimen
category_counts = df_final['sentiment'].value_counts()

# Membuat pie chart
category_counts.plot.pie(
    autopct='%1.1f%%',
    colors=['lightcoral', 'skyblue', 'lightgreen'],
    startangle=90
)

# Menambahkan judul
plt.title('Distribusi Kategori Sentimen')

# Menghilangkan label y
plt.ylabel('')

# Menampilkan chart
plt.show()

# %% [markdown]
# ###Interpretasi
# - Mayoritas netizen bersentimen negatif (58.5%), mencerminkan keraguan terhadap kesiapan pemerintah.
#
# - Sentimen netral (25.5%) menunjukkan sikap menunggu kejelasan teknis.
#
# - Sentimen positif (15.9%) masih rendah, menandakan minimnya dukungan terhadap keputusan MK.

# %% [markdown]
# ##Perbandingan distribusi sentimen pada twitter dan youtube

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Hitung distribusi sentimen untuk Twitter dan Youtube
sentiment_counts_tweet = df_tweet['sentiment'].value_counts().sort_index()
sentiment_counts_youtube = df_youtube['sentiment'].value_counts().sort_index()

# Hitung persentase masing-masing sentimen per platform
sentiment_pct_tweet = (sentiment_counts_tweet / sentiment_counts_tweet.sum()) * 100
sentiment_pct_youtube = (sentiment_counts_youtube / sentiment_counts_youtube.sum()) * 100

# Gabungkan data persentase sentimen untuk kedua platform ke dalam satu DataFrame
sentiment_comparison_pct = pd.DataFrame({
    'Twitter (%)': sentiment_pct_tweet,
    'Youtube (%)': sentiment_pct_youtube
}).fillna(0)

# Buat bar plot perbandingan persentase
plt.figure(figsize=(8, 6))
ax = sentiment_comparison_pct.plot(kind='bar', ax=plt.gca(), color=['skyblue', 'lightcoral'])
plt.title('Perbandingan Distribusi Sentimen pada Twitter dan Youtube (dalam %)')
plt.xlabel('Sentimen')
plt.ylabel('Persentase (%)')
plt.xticks(rotation=0)
plt.legend(title='Platform')
plt.tight_layout()

# Tambahkan label persentase di atas setiap batang
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(
            p.get_x() + p.get_width() / 2,
            height + 1,  # sedikit offset supaya label tidak nempel batang
            f'{height:.1f}%',
            ha='center',
            va='bottom',
            fontsize=9)

plt.show()

# %% [markdown]
# ###Interpretasi
# - Sentimen negatif dominan di kedua platform, terutama di YouTube.
#
# - Twitter lebih banyak mengandung sentimen netral.
#
# - YouTube memiliki sentimen positif lebih tinggi dibanding Twitter.
#
# Secara umum, YouTube cenderung lebih emosional, Twitter lebih netral.

# %% [markdown]
# #Word Cloud

# %%
# Mengolah kembali stopword, karena terdapat kata-kata baru yang mengganggu Word Cloud
# Hal ini di karenakan kata-kata tersebut muncul di semua kategori (di permasalahan sentimen)
# stopword khusus
stopword_nat = {'sekolah','swasta','negeri','gratis','sd','smp',
                'putusan','mk','sd-smp','pemerintah','iya'}

# %%
# Install the library if not already installed
# !pip install textblob

# Fungsi Pembersih stopword
from textblob import TextBlob # Import TextBlob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.11/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
# Fungsi Pembersih stopword
# !pip install textblob nltk
from textblob import TextBlob
import nltk

try:
    TextBlob("").tokenize()
except LookupError:
    print("Downloading TextBlob corpora...")
    # !python -m textblob.download_corpora

def clean_text(text, stopwords):
    if not isinstance(text, str):
        return ""

    # Mengubah teks menjadi huruf kecil
    text = text.lower()

    # Tokenisasi menggunakan TextBlob
    tokens = TextBlob(text).words

    # Menghapus stopwords
    filtered_tokens = [token for token in tokens if token not in stopwords]

    # Menggabungkan kembali token menjadi teks
    return ' '.join(filtered_tokens)

# Membuat kolom baru tanpa stopword khusus
# Pastikan kolom yang akan diproses ada di DataFrame
if 'stemmed_text' in df_final.columns:
    df_final['stemmed_text_new'] = df_final['stemmed_text'].apply(lambda x: clean_text(x, stopword_nat))
    print("Column 'stemmed_text_new' created successfully.")
else:
    print("Error: Column 'stemmed_text' not found in the DataFrame.")

df_final.head()
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Column 'stemmed_text_new' created successfully.
#                                                 text sentiment username  \
# 0  MK Putuskan SD-SMP Swasta Gratis Komisi X DPR ...   neutral      NaN
# 1  Komisi X DPR RI berkomitmen mengawal implement...   neutral      NaN
# 2  MK Putuskan SD-SMA Negeri dan Swasta Gratis Pa...   neutral      NaN
# 3  Respons Wamendagri Bima Arya soal Pendidikan G...   neutral      NaN
# 4  Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral      NaN
#
#             created_at  likes  reply_count  \
# 0  2025-05-30 04:22:59    1.0            0
# 1  2025-05-30 04:19:07    0.0            0
# 2  2025-05-30 04:11:28    3.0            2
# 3  2025-05-30 04:03:08    3.0            0
# 4  2025-05-30 03:50:46    0.0            0
#
#                                                  url  \
# 0  https://x.com/undefined/status/192830611885126...
# 1  https://x.com/undefined/status/192830514333582...
# 2  https://x.com/undefined/status/192830322054963...
# 3  https://x.com/undefined/status/192830112260070...
# 4  https://x.com/undefined/status/192829801043108...
#
#                                                  new  \
# 0  MK Putuskan Sekolah Dasar-Sekolah Menengah Per...
# 1  Komisi X DPR RI berkomitmen mengawal implement...
# 2  MK Putuskan Sekolah Dasar-Sekolah Menengah Ata...
# 3  Respons Wamendagri Bima Arya soal Pendidikan G...
# 4  Respons Pemkab Bantul Soal Putusan MK tentang ...
#
#                                             cleaning  \
# 0  mk putuskan sekolah dasarsekolah menengah pert...
# 1  komisi x dpr ri berkomitmen mengawal implement...
# 2  mk putuskan sekolah dasarsekolah menengah atas...
# 3  respons wamendagri bima arya soal pendidikan g...
# 4  respons pemkab bantul soal putusan mk tentang ...
#
#                                         no_stopwords  \
# 0  mk putuskan sekolah dasarsekolah menengah swas...
# 1  komisi x dpr ri berkomitmen mengawal implement...
# 2  mk putuskan sekolah dasarsekolah menengah nege...
# 3  respons wamendagri bima arya pendidikan gratis...
# 4  respons pemkab bantul putusan mk sekolah grati...
#
#                                         stemmed_text  engagement  \
# 0  mk putus sekolah dasarsekolah tengah swasta gr...         1.0
# 1  komisi x dpr ri komitmen awal implementasi put...         0.0
# 2  mk putus sekolah dasarsekolah tengah negeri sw...         5.0
# 3  respons wamendagri bima arya pendidikan gratis...         3.0
# 4  respons pemkab bantul putus mk sekolah gratis ...         0.0
#
#                                     stemmed_text_new
# 0  putus dasarsekolah tengah komisi x dpr dorong ...
# 1  komisi x dpr ri komitmen awal implementasi put...
# 2  putus dasarsekolah tengah pakar pendidikan ama...
# 3  respons wamendagri bima arya pendidikan putus ...
# 4                        respons pemkab bantul putus

# %%
# Fungsi untuk memanggil baris yang mengandung beberapa keyword
def filter_teks_multi_kata(df_final, kolom, kata_kunci):
    # Membuat filter untuk semua kata kunci
    mask = df_final[kolom].str.contains(kata_kunci[0], case=False, na=False)
    for kata in kata_kunci[1:]:
        mask &= df_final[kolom].str.contains(kata, case=False, na=False)
    return df_final[mask]

# %%
# !pip install wordcloud

from wordcloud import WordCloud
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.2.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %% [markdown]
# ##Wordcloud Positif

# %%
dfpos = df_final[df_final['sentiment']=='positive']

# %%
# Gabungkan kolom teks jika ada
text = " ".join(dfpos['stemmed_text_new'])

# Generate dan tampilkan word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# melihat isi tweet berdasarkan beberapa kata kunci yang besar
dfposwhat = filter_teks_multi_kata(dfpos, 'stemmed_text_new', ['pendidikan','biaya'])
listpos = list(dfposwhat['text'])
listurlpos = list(dfposwhat['url'])
for i in range(len(listpos)):
  print(f"{i+1}. Link [{listurlpos[i]}] : {listpos[i]}")
# Out:
# 1. Link [https://x.com/undefined/status/1927847760046506335] : @glrhn Putusan MK ini adalah tamparan sekaligus harapan. Tamparan bagi negara yang terlalu lama abai. Harapan bagi jutaan anak bangsa yang terhalang biaya. Pendidikan adalah hak bukan kemewahan yang hanya bisa dibeli. Gratis di sekolah negeri saja tak cukup karena kenyataannya
# 2. Link [https://x.com/undefined/status/1928060084166316513] : sudah benar wajib belajar 12 tahun hingga SMA merata ke semua daerah sekarang diputuskan bebas biaya pendidikan dari SD sampai SMP termasuk sekolah Swasta --- ongkos antar jemput 1 siswa pakai mobil di Sekolahan Elit bakal berat kalau ditanggung juga sama Pemerintah ---
# 3. Link [https://x.com/undefined/status/1928025580341186966] : @strawbewwywy @tanyarlfes UUD menyebutkan warga negara wajib mengikuti pendidikan dasar dan Pemerintah wajib membiayainya. Sedari awal memang harus dibiayai karena ga semua orang bisa sekolah negeri. Sekolah swastapun ada yang gak sepakat pas sidang ini tapi ini amanat konstitusi.
# 4. Link [https://x.com/undefined/status/1927937190845096259] : Penggratisan sekolah swasta bukan berarti swasta dipaksa untuk tidak mengambil biaya sekolah. Tapi lewat keputusan MK ini pemerintah punya kewajiban untuk membayar biaya pendidikan bagi para siswa yg belajar di sekolah swasta.
# 5. Link [https://x.com/undefined/status/1927614426179580378] : @wannasober @detikcom Pemerintah Indonesia harus mendanai pendidikan dasar gratis di sekolah swasta dan negeri kemungkinan melalui subsidi dari anggaran pendidikan 2025 (IDR 724 triliun). Biaya seperti gaji guru perawatan gedung dan alat bantu belajar akan ditanggung negara tapi anggaran terbatas
# 6. Link [https://x.com/undefined/status/1927345817406300254] : Komen Pa menteri ini jd kopling: Tetapi pelaksanaannya DISESUAIKAN dengan kemampuan fiskal pemerintah. Dan sekolah swasta tetap dapat memungut biaya pendidikan dari masyarakat meski ada bantuan pembiayaan dari pemerintah ucapnya. https://t.co/J1AxBmwoGD
# 29. Link [nan] : Definisi gratisnya yang mungkin perlu diperjelas. Apakah gratis 100%, atau SPP, atau uang gedung, atau seragam?
#
# Karena kalau diswasta, itu kadang item pembiayaannya banyak banget. Ada uang gedung, SPP, kegiatan, buku, seragam, ujian sampai asuransi kesehatan.
#
# Jadi, apanya yang mau digratiskan?
#
# Namun demikian, sungguh ini adalah langkah berani untuk meningkatkan kecerdasan bangsa Indonesia. Agar bisa jaya dan mendunia, seperti para leluhur kita.
# 30. Link [nan] : kalau memang putusan seperti itu, pemerintah juga harus memposisikan sekolah negeri dan swasta dengan sama dan adil, dalam segala hal dari segi pembiayaan pendidikan dan kesejahteraan tenaga pendidiknya
# 31. Link [nan] : Siap2.... Yg di lingkungan ASN  ada pengurangan biaya, penghematan bhkn pengurangan pegawai.. Bisa jd krna hal  pendidikan gratis.
# 32. Link [nan] : Semuanya tergantung rencana pemerintah dan biaya yg cepat,  tepat dan terukur dgn pengawasan pelaksanaan anggaran yg digelontorkan,  sementara makan bergizi gratis dgn  gizinya yg cukup lbh baik dialihkan sana ke dana pendidikan
# 33. Link [nan] : Terimakasih kepada presenter yg menitipkan suaranya untuk kesejahteraan guru.. <br>Karena salah satu alasan sekolah swasta memungut biaya pendidikan juga untuk memberikan honor bulanan untuk para guru..<br>Adanya peningkatan penerimaan dana sertifikasi untuk setiap guru yg sdh profesional mmg sudah sangat membantu, namun itu sifatnya tunjangan sedangkan honor bulanannya tidak bisa dianggarkan dr APBN maupun APBD.
# 34. Link [nan] : dana MBG diganti jadi biaya pendidikan gratis, begitu lebih tepat sasaran

# %% [markdown]
# ###Interpretasi
# Secara keseluruhan, word cloud mencerminkan euforia dan dukungan masyarakat (“alhamdulillah, bagus”) terhadap kebijakan “pendidikan” gratis, sekaligus kekhawatiran terkait detail pendanaan (“biaya, bayar”) dan harapan agar peran “pemerintah” dalam menjamin pendidikan gratis benar-benar terlaksana.

# %% [markdown]
# #wordcloud negatif

# %%
dfneg = df_final[df_final['sentiment']=='negative']

# %%
# Gabungkan kolom teks jika ada
text = " ".join(dfneg['stemmed_text_new'])

# Generate dan tampilkan word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# melihat isi tweet berdasarkan beberapa kata kunci yang besar
dfnegwhat = filter_teks_multi_kata(dfneg, 'stemmed_text_new', ['biaya','bayar'])
listpos = list(dfnegwhat['text'])
listurlpos = list(dfnegwhat['url'])
for i in range(len(listpos)):
  print(f"{i+1}. Link [{listurlpos[i]}] : {listpos[i]}")
# Out:
# 1. Link [https://x.com/undefined/status/1928138341725126904] : Kenapa malah ngurusin biaya sekolah swasta.. padahal di sekolah negri yang harusnya gratis aja masih banyak [banget] yang nyogok beli bangku iuran ini itu ratusan ribu perbulan bayangin kita semua bayar pajak buat gaji pemerintah yang kerjanya asbun gak jelas begini
# 2. Link [https://x.com/undefined/status/1927971753688445259] : @tanyakanrl sekolah swasta yg gimana dl nih?. emang klo gratisin pemerintah kuat bayar operasional sekolah2 yang berbiaya tinggi.
# 4  Respons Pemkab Bantul Soal Putusan MK tentang ...   neutral      NaN
#
#             created_at  likes  reply_count  \
# 0  2025-05-30 04:22:59    1.0            0
# 1  2025-05-30 04:19:07    0.0            0
# 2  2025-05-30 04:11:28    3.0            2
# 3  2025-05-30 04:03:08    3.0            0
# 4  2025-05-30 03:50:46    0.0            0
#
#                                                  url  sentiment_num  \
# 0  https://x.com/undefined/status/192830611885126...            2.0
# 1  https://x.com/undefined/status/192830514333582...            2.0
# 2  https://x.com/undefined/status/192830322054963...            2.0
# 3  https://x.com/undefined/status/192830112260070...            2.0
# 4  https://x.com/undefined/status/192829801043108...            2.0
#
#                                                  new  \
# 0  MK Putuskan Sekolah Dasar-Sekolah Menengah Per...
# 1  Komisi X DPR RI berkomitmen mengawal implement...
# 2  MK Putuskan Sekolah Dasar-Sekolah Menengah Ata...
# 3  Respons Wamendagri Bima Arya soal Pendidikan G...
# 4  Respons Pemkab Bantul Soal Putusan MK tentang ...
#
#                                             cleaning  \
# 0  mk putuskan sekolah dasarsekolah menengah pert...
# 1  komisi x dpr ri berkomitmen mengawal implement...
# 2  mk putuskan sekolah dasarsekolah menengah atas...
# 3  respons wamendagri bima arya soal pendidikan g...
# 4  respons pemkab bantul soal putusan mk tentang ...
#
#                                         no_stopwords  \
# 0  mk putuskan sekolah dasarsekolah menengah swas...
# 1  komisi x dpr ri berkomitmen mengawal implement...
# 2  mk putuskan sekolah dasarsekolah menengah nege...
# 3  respons wamendagri bima arya pendidikan gratis...
# 4  respons pemkab bantul putusan mk sekolah grati...
#
#                                         stemmed_text
# 0  mk putus sekolah dasarsekolah tengah swasta gr...
# 1  komisi x dpr ri komitmen awal implementasi put...
# 2  mk putus sekolah dasarsekolah tengah negeri sw...
# 3  respons wamendagri bima arya pendidikan gratis...
# 4  respons pemkab bantul putus mk sekolah gratis ...

# %%
# Ubah kolom created_at ke format datetime
ams['created_at'] = pd.to_datetime(ams['created_at'])

# Buat kolom tanggal saja (tanpa jam)
ams['date'] = ams['created_at'].dt.date

# Hitung jumlah tweet per kategori sentimen per hari
sentiment_per_day = ams.groupby(['date', 'sentiment']).size().unstack(fill_value=0)

# %%
yt = ams[ams['url'].isnull()]
x = ams[ams['url'].notnull()]

# Pastikan kolom 'created_at' sudah datetime
yt['created_at'] = pd.to_datetime(yt['created_at'])
x['created_at'] = pd.to_datetime(x['created_at'])

# Konversi kolom 'created_at' menjadi format datetime jika belum
yt['created_at'] = pd.to_datetime(yt['created_at'])
x['created_at'] = pd.to_datetime(x['created_at'])

# Agregasi data berdasarkan waktu (per hari), dan hitung jumlah sentimen per hari
yt_sentiment = yt.groupby([yt['created_at'].dt.date, 'sentiment']).size().unstack(fill_value=0)
x_sentiment = x.groupby([x['created_at'].dt.date, 'sentiment']).size().unstack(fill_value=0)
# Out:
# <ipython-input-5-a4e9637b4dcd>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yt['created_at'] = pd.to_datetime(yt['created_at'])
# <ipython-input-5-a4e9637b4dcd>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['created_at'] = pd.to_datetime(x['created_at'])
# <ipython-input-5-a4e9637b4dcd>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yt['created_at'] = pd.to_datetime(yt['created_at'])
# <ipython-input-5-a4e9637b4dcd>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['created_at'] = pd.to_datetime(x['created_at'])

# %% [markdown]
# #Visualisasi Time Series

# %%
plt.figure(figsize=(12,6))

# Plot setiap sentimen dengan warna khusus
sentiment_per_day['positive'].plot(label='positive', color='green', marker='o')
sentiment_per_day['neutral'].plot(label='neutral', color='orange', marker='o')
sentiment_per_day['negative'].plot(label='negative', color='red', marker='o')  # merah

# Format grafik
plt.title('Tren Sentimen Harian Terkait SD-SMP Gratis')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Tweet')
plt.grid(True)
plt.legend(title='Sentimen')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Visualisasi X dan Youtube

# %%
# Plot Time Series untuk Sentimen antara Platform dengan URL dan Tanpa URL
plt.figure(figsize=(12, 5))

# Subplot untuk data tanpa URL (yt)
plt.subplot(1, 2, 1)
yt_sentiment.plot(kind='area', stacked=True, ax=plt.gca(), color=['#ff6347', '#ffeb3b', '#32cd32'])  # Merah, Kuning, Hijau
plt.title('Distribusi Sentimen Youtube')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Postingan')
plt.xticks(rotation=45)

# Subplot untuk data dengan URL (x)
plt.subplot(1, 2, 2)
x_sentiment.plot(kind='area', stacked=True, ax=plt.gca(), color=['#ff6347', '#ffeb3b', '#32cd32'])  # Merah, Kuning, Hijau
plt.title('Distribusi Sentimen Twitter')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Postingan')
plt.xticks(rotation=45)

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter berdasarkan tanggal untuk YouTube
start_date = pd.to_datetime('2025-05-27')
end_date = pd.to_datetime('2025-05-30')

# Filter data berdasarkan rentang tanggal untuk yt (YouTube)
yt_filtered = yt[(yt['created_at'] >= start_date) & (yt['created_at'] <= end_date)]
x_filtered = x[(x['created_at'] >= start_date) & (x['created_at'] <= end_date)]

# Agregasi data berdasarkan waktu (per hari), dan hitung jumlah sentimen per hari
yt_sentiment = yt_filtered.groupby([yt_filtered['created_at'].dt.date, 'sentiment']).size().unstack(fill_value=0)
x_sentiment = x_filtered.groupby([x_filtered['created_at'].dt.date, 'sentiment']).size().unstack(fill_value=0)

# Plot Time Series untuk Sentimen antara Platform dengan URL dan Tanpa URL
plt.figure(figsize=(12, 5))

# Subplot untuk data tanpa URL (yt)
plt.subplot(1, 2, 1)
yt_sentiment.plot(kind='area', stacked=True, ax=plt.gca(), color=['#ff6347', '#ffeb3b', '#32cd32'])  # Merah, Kuning, Hijau
plt.title('Distribusi Sentimen Youtube')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Postingan')
plt.xticks(rotation=45)

# Subplot untuk data dengan URL (x)
plt.subplot(1, 2, 2)
x_sentiment.plot(kind='area', stacked=True, ax=plt.gca(), color=['#ff6347', '#ffeb3b', '#32cd32'])  # Merah, Kuning, Hijau
plt.title('Distribusi Sentimen Twitter')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Postingan')
plt.xticks(rotation=45)

# Menampilkan plot
plt.tight_layout()
plt.show()
